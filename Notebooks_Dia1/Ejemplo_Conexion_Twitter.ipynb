# %%
# %pip install tweepy

# %%
import tweepy
from twitter_secrets import CONSUMER_KEY, CONSUMER_SECRET, ACCESS_TOKEN, ACCESS_TOKEN_SECRET

auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)

api = tweepy.API(auth)

#timeline de el dueño de acces_token
#Returns the 20 most recent statuses, including retweets, posted by the authenticating user and that user’s friends. This is the equivalent of /timeline/home on the Web.
public_tweets = api.home_timeline()

print(type(public_tweets))
print("-------")

for tweet in public_tweets:
    print(tweet.text)
    print("-------")
# Out:
# <class 'tweepy.models.ResultSet'>
# -------
# En la micropíldora de hoy,  Javier González, Jefe Dpto. Técnico de Informática de @GrupoPancorbo nos da algunos tip… https://t.co/UgC0TuWAy8
# -------
# Andreu ha destacado que «es el momento de diseñar la región que queremos entre todos» https://t.co/F426dcnlxs
# -------
# "The coronavirus disaster is not a discrete event ... The outcomes we’re currently coping with may appear sudden bu… https://t.co/1h94vI4WbS
# -------
# OK, robots, we see you 👀 https://t.co/sRwmect2KF
# -------
# ¡¡¡A por ello!!!!
#
# The Ultimate Guide to RHCSA Certification Exam
# Become a red hat certified system administrator b… https://t.co/ni1qFTWlzI
# -------
# Deportes en #MasdeunoLaRioja "Vaya lío que tenemos para no tener nada" #Fase2 #LaRioja
# https://t.co/Vth21UfKUc https://t.co/qAVtiaoazd
# -------
# The current season of 'Masterchef Australia' kept filming when social distancing came into effect earlier this year. https://t.co/bNY9GEsQDs
# -------
# ...

# %%
#Returns information about the specified user.
api.get_user('telecos_rioja')
# Out:
# User(_api=<tweepy.api.API object at 0x109463f90>, _json={'id': 243809723, 'id_str': '243809723', 'name': 'AITER - Ingenieros de Telecomunicación La Rioja', 'screen_name': 'telecos_rioja', 'location': 'La Rioja, Spain', 'profile_location': None, 'description': 'Twitter oficial de la Asociación de Ingenieros de #Telecomunicación de #LaRioja.', 'url': 'https://t.co/5vs5YdyO6q', 'entities': {'url': {'urls': [{'url': 'https://t.co/5vs5YdyO6q', 'expanded_url': 'https://www.aiter.org', 'display_url': 'aiter.org', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 367, 'friends_count': 43, 'listed_count': 17, 'created_at': 'Thu Jan 27 21:27:39 +0000 2011', 'favourites_count': 510, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1901, 'lang': None, 'status': {'created_at': 'Tue May 26 10:39:01 +0000 2020', 'id': 1265230958258728960, 'id_str': '1265230958258728960', 'text': 'La cobertura de banda ancha l
# ...

# %%
api.get_user('thinktic')
# Out:
# User(_api=<tweepy.api.API object at 0x103e1e350>, _json={'id': 85380154, 'id_str': '85380154', 'name': 'Thinktic', 'screen_name': 'Thinktic', 'location': 'La Rioja (Spain)', 'profile_location': None, 'description': 'Centro Nacional de Formación en Nuevas Tecnologias  - ThinkTic', 'url': 'http://t.co/VNrENEt17J', 'entities': {'url': {'urls': [{'url': 'http://t.co/VNrENEt17J', 'expanded_url': 'http://www.larioja.org/thinktic', 'display_url': 'larioja.org/thinktic', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 3007, 'friends_count': 457, 'listed_count': 203, 'created_at': 'Mon Oct 26 18:31:35 +0000 2009', 'favourites_count': 401, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 4624, 'lang': None, 'status': {'created_at': 'Mon May 25 11:50:20 +0000 2020', 'id': 1264886515441729536, 'id_str': '1264886515441729536', 'text': 'Los tres mordiscos de la obsolescencia programada al medioambiente http
# ...

# %%
#Returns an array containing the IDs of users following the specified user.
followers = api.followers_ids('thinktic')
print(len(followers))
print(followers)
# Out:
# 3006
# ...

# %%
#Returns an array containing the IDs of users following the specified user.
followers = api.followers_ids('jecrespom')
print(len(followers))
print(followers)
# Out:
# 2606
# ...

# %%
#Segundo nivel del usuario jecrespom
#Llegará al límite de 15 consultas cada 15 minutos. Rate Limit Error
for f in followers:
    f2 = api.followers_ids(f)
    print(len(f2))
    print(f2)
    print("-------")
# Out:
# 1282
# ...

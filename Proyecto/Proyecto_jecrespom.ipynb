# %%
#proyecto curso análisis RRSS con Python

# %%
#CAPTURA DE DATOS

# %%
#Conectarnos a la API de Twitter para recopilar datos.

# %%
import time
import tweepy
from twitter_secrets import CONSUMER_KEY, CONSUMER_SECRET, ACCESS_TOKEN, ACCESS_TOKEN_SECRET

auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)

api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify= True) #así espera y notifica

try:
    api.verify_credentials()
    print("Autentificación OK")
except tweepy.TweepError as e:
    print("Falló la autentificación")
    print(e)
# Out:
# Autentificación OK

# %%
#generar nuestra red la lista de seguidores (followers) y seguidos (friends) de la red del usuario jecrespom

# %%
#Returns an array containing the IDs of users following jecrespom.
followers = api.followers_ids('jecrespom')
print(len(followers))

#da un máximo de 5000 folowers, si tiene más, debo usar el cursor para no repetir
#Y solo puedo hacer 15 peticiones cada 15 minutos, por lo que solo puedo hacer 75000 followers cada 15 minutos
#ejemplo seguidores alo_oficial
'''
pos = 0
for follower_id in tweepy.Cursor(api.followers_ids,"alo_oficial").items():
    print(f'{pos:06d}:{follower_id}')
    pos = pos + 1
'''
# Out:
# 2602
# '\npos = 0\nfor follower_id in tweepy.Cursor(api.followers_ids,"alo_oficial").items():\n    print(f\'{pos:06d}:{follower_id}\')\n    pos = pos + 1\n'

# %%
#Returns an array containing the IDs of users being followed by jecrespom
friends = api.friends_ids('jecrespom')
print(len(friends))
# Out:
# 746

# %%
#Procesar los datos y generar un fichero en formato edgelist de relaciones entre usuarios.
#recojo los followers de segundo nivel de jecrespom y los friends de segundo nivel

# %%
followers_d = {}
n = 0 #consultas a la api para followers
for follower_id in followers:
    if follower_id in followers_d:
        print(f'El usuario {follower_id} ya se ha descargado')
        continue
    
    print(f'Follower --------->{follower_id}')
    followers_d[follower_id] = [] #lista de follower de mi follower
    
    try:
        #followers_hijo=api.followers_ids(follower_id)
        #followers_ids da un máximo de 5000, si hay más, debo usar Cursor y hacer peticiones
        #Ver: https://developer.twitter.com/en/docs/accounts-and-users/follow-search-get-users/api-reference/get-friends-ids
        #Limito a coger 300k followers que son 1 hora con las limitaciones de la api
        #followers=api.followers_ids(follower_id)
        #followers_d[follower_id] = followers
        #como tengo 2600 seguidores y los puedo consultar 1, cuesta casi dos dias tener los seguidores de mis followers
        n+=1
        for followers_hijo in tweepy.Cursor(api.followers_ids,follower_id).items(300000):
            followers_d[follower_id].append(followers_hijo)
            
        print(f'{n} - El follower {follower_id} tiene {len(followers_d[follower_id])} seguidores')
    except tweepy.TweepError as e:
        if 'Not authorized' in str(e):
            print(f'{n} - El usuario {follower_id} no nos deja acceder a sus datos')
        else:
            print(e)
            time.sleep(60)
# Out:
# Follower --------->1138115772
# 1 - El follower 1138115772 tiene 111 seguidores
# Follower --------->867052638873022464
# 2 - El follower 867052638873022464 tiene 98 seguidores
# Follower --------->93147038
# 3 - El follower 93147038 tiene 1283 seguidores
# Follower --------->1690789872
# 4 - El follower 1690789872 tiene 413 seguidores
# Follower --------->3298925390
# 5 - El follower 3298925390 tiene 64 seguidores
# Follower --------->848918106
# 6 - El usuario 848918106 no nos deja acceder a sus datos
# Follower --------->1648904448
# 7 - El usuario 1648904448 no nos deja acceder a sus datos
# Follower --------->1258422929295056903
# 8 - El follower 1258422929295056903 tiene 7 seguidores
# Follower --------->795938924489281536
# 9 - El follower 795938924489281536 tiene 945 seguidores
# Follower --------->63600623
# 10 - El follower 63600623 tiene 117 seguidores
# Follower --------->1254739233459376129
# 11 - El follower 1254739233459376129 tiene 994 seguidores
# Follower --------->1203014081566969858
# 12 - El follower 1203014081566969858 tiene 3 seguidores
# Follower --------->2738058851
# 13 - El usuario 2738058851 no nos deja acceder a sus datos
# Follower --------->207158301
# 14 - El follower 207158301 tiene 404 seguidores
# Follower --------->910954837
# Rate limit reached. Sleeping for: 891
# 15 - El follower 910954837 tiene 74 seguidores
# Follower --------->269006291
# 16 - El follower 269006291 tiene 175 seguidores
# Follower --------->1226064262709334016
# 17 - El follower 1226064262709334016 tiene 91 seguidores
# Follower --------->1142076991455289351
# 18 - El follower 1142076991455289351 tiene 61 seguidores
# Follower --------->107189419
# 19 - El follower 107189419 tiene 342 seguidores
# Follower --------->271178681
# 20 - El follower 271178681 tiene 82 seguidores
# Follower --------->406596269
# 21 - El usuario 406596269 no nos deja acceder a sus datos
# Follower --------->1077604505401913344
# 22 - El follower 1077604505401913344 tiene 19 seguidores
# Follower --------->1071698929
# 23 - El follower 1071698929 tiene 19 seguidores
# Follower --------->315765618
# 24 - El follower 315765618 tiene 215 seguidores
# Follower --------->971178019590205440
# 25 - El follower 971178019590205440 tiene 26 seguidores
# Follower --------->335359705
# 26 - El follower 335359705 tiene 487 seguidores
# Follower --------->955923421
# 27 - El follower 955923421 tiene 21 seguidores
# Follower --------->1661110783
# 28 - El follower 1661110783 tiene 175 seguidores
# Follower --------->933765574982885376
# 29 - El follower 933765574982885376 tiene 80 seguidores
# Follower --------->970438251189239808
# Rate limit reached. Sleeping for: 895
# Failed to send request: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Follower --------->3253367533
# 31 - El follower 3253367533 tiene 125 seguidores
# Follower --------->974998462101106688
# 32 - El follower 974998462101106688 tiene 56 seguidores
# Follower --------->3319318173
# 33 - El follower 3319318173 tiene 4326 seguidores
# Follower --------->93881212
# 34 - El follower 93881212 tiene 154 seguidores
# Follower --------->192897149
# 35 - El follower 192897149 tiene 93 seguidores
# Follower --------->1242800864005443584
# 36 - El follower 1242800864005443584 tiene 221 seguidores
# Follower --------->1240688968808701953
# 37 - El follower 1240688968808701953 tiene 13 seguidores
# Follower --------->2212461865
# 38 - El follower 2212461865 tiene 685 seguidores
# Follower --------->1118927846678958085
# 39 - El follower 1118927846678958085 tiene 4 seguidores
# Follower --------->724669800748818432
# 40 - El follower 724669800748818432 tiene 135 seguidores
# Follower --------->1086733250498908160
# 41 - El follower 1086733250498908160 tiene 233 seguidores
# Follower --------->338603142
# 42 - El follower 338603142 tiene 248 seguidores
# Follower --------->9399452
# 43 - El follower 9399452 tiene 191 seguidores
# Follower --------->1229162687218712578
# 44 - El follower 1229162687218712578 tiene 137 seguidores
# Follower --------->1240379998940389379
# 45 - El follower 1240379998940389379 tiene 1 seguidores
# Follower --------->1014114645047758848
# Rate limit reached. Sleeping for: 895
# Failed to send request: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Follower --------->1231089713408348161
# 47 - El usuario 1231089713408348161 no nos deja acceder a sus datos
# Follower --------->3105980830
# 48 - El follower 3105980830 tiene 155 seguidores
# Follower --------->1160231561507291136
# 49 - El follower 1160231561507291136 tiene 3 seguidores
# Follower --------->728137388
# 50 - El follower 728137388 tiene 479 seguidores
# Follower --------->172801059
# 51 - El follower 172801059 tiene 57 seguidores
# Follower --------->61169476
# 52 - El follower 61169476 tiene 252 seguidores
# Follower --------->18474421
# 53 - El follower 18474421 tiene 831 seguidores
# Follower --------->60152351
# 54 - El follower 60152351 tiene 772 seguidores
# Follower --------->266197553
# 55 - El follower 266197553 tiene 596 seguidores
# Follower --------->701018446704803840
# 56 - El follower 701018446704803840 tiene 7 seguidores
# Follower --------->917968321
# 57 - El follower 917968321 tiene 1271 seguidores
# Follower --------->3288081239
# 58 - El follower 3288081239 tiene 4060 seguidores
# Follower --------->3919851418
# 59 - El follower 3919851418 tiene 5272 seguidores
# Follower --------->1173624533636583424
# 60 - El follower 1173624533636583424 tiene 341 seguidores
# Follower --------->19412575
# Rate limit reached. Sleeping for: 894
# 61 - El follower 19412575 tiene 91 seguidores
# Follower --------->1226677471929495555
# 62 - El usuario 1226677471929495555 no nos deja acceder a sus datos
# Follower --------->896665173657886721
# 63 - El follower 896665173657886721 tiene 147 seguidores
# Follower --------->783287228
# 64 - El follower 783287228 tiene 3410 seguidores
# Follower --------->308451924
# 65 - El follower 308451924 tiene 799 seguidores
# Follower --------->1228728758883909632
# 66 - El follower 1228728758883909632 tiene 7 seguidores
# Follower --------->864804906317819904
# 67 - El follower 864804906317819904 tiene 122 seguidores
# Follower --------->887644903077019648
# 68 - El follower 887644903077019648 tiene 11839 seguidores
# Follower --------->1218127790106648576
# 69 - El follower 1218127790106648576 tiene 6 seguidores
# Follower --------->1102699144496451586
# 70 - El follower 1102699144496451586 tiene 39 seguidores
# Follower --------->2578600342
# 71 - El usuario 2578600342 no nos deja acceder a sus datos
# Follower --------->1119303015729651712
# 72 - El usuario 1119303015729651712 no nos deja acceder a sus datos
# Follower --------->3228488541
# 73 - El follower 3228488541 tiene 167 seguidores
# Follower --------->826855556979761152
# Rate limit reached. Sleeping for: 893
# 74 - El follower 826855556979761152 tiene 4648 seguidores
# Follower --------->986219887088500736
# 75 - El follower 986219887088500736 tiene 33 seguidores
# Follower --------->838724315545743361
# 76 - El follower 838724315545743361 tiene 1731 seguidores
# Follower --------->1216491224166731777
# 77 - El follower 1216491224166731777 tiene 114 seguidores
# Follower --------->1009074100436946946
# 78 - El follower 1009074100436946946 tiene 24 seguidores
# Follower --------->1222812088407674881
# 79 - El follower 1222812088407674881 tiene 1175 seguidores
# Follower --------->970989441421594624
# 80 - El follower 970989441421594624 tiene 224 seguidores
# Follower --------->1096215827106463744
# 81 - El follower 1096215827106463744 tiene 106 seguidores
# Follower --------->229939190
# 82 - El follower 229939190 tiene 95 seguidores
# Follower --------->1220356864417943554
# 83 - El follower 1220356864417943554 tiene 429 seguidores
# Follower --------->1108494962885382144
# 84 - El follower 1108494962885382144 tiene 356 seguidores
# Follower --------->802453710584639488
# 85 - El follower 802453710584639488 tiene 8 seguidores
# Follower --------->2871199970
# 86 - El usuario 2871199970 no nos deja acceder a sus datos
# Follower --------->17675782
# 87 - El usuario 17675782 no nos deja acceder a sus datos
# Follower --------->91853816
# 88 - El follower 91853816 tiene 169 seguidores
# Follower --------->1920151681
# Rate limit reached. Sleeping for: 892
# 89 - El follower 1920151681 tiene 1241 seguidores
# Follower --------->75504143
# 90 - El usuario 75504143 no nos deja acceder a sus datos
# Follower --------->1183781521423044609
# 91 - El follower 1183781521423044609 tiene 39 seguidores
# Follower --------->279884520
# 92 - El follower 279884520 tiene 67 seguidores
# Follower --------->240850305
# 93 - El follower 240850305 tiene 51 seguidores
# Follower --------->958592125238763520
# 94 - El follower 958592125238763520 tiene 228 seguidores
# Follower --------->14597867
# 95 - El follower 14597867 tiene 185 seguidores
# Follower --------->1179760149952679941
# 96 - El follower 1179760149952679941 tiene 73 seguidores
# Follower --------->268635695
# 97 - El follower 268635695 tiene 36 seguidores
# Follower --------->172869037
# 98 - El usuario 172869037 no nos deja acceder a sus datos
# Follower --------->976188704757895168
# 99 - El follower 976188704757895168 tiene 58 seguidores
# Follower --------->1207617029118840839
# 100 - El follower 1207617029118840839 tiene 11 seguidores
# Follower --------->835865257088274432
# 101 - El follower 835865257088274432 tiene 1441 seguidores
# Follower --------->861581623543967745
# 102 - El follower 861581623543967745 tiene 39 seguidores
# Follower --------->1149975272990617600
# 103 - El follower 1149975272990617600 tiene 4 seguidores
# Follower --------->2272072375
# Rate limit reached. Sleeping for: 894
# Failed to send request: ('Connection aborted.', OSError("(54, 'ECONNRESET')"))
# Follower --------->908137150037872642
# 105 - El follower 908137150037872642 tiene 1 seguidores
# Follower --------->3612606694
# 106 - El follower 3612606694 tiene 5 seguidores
# Follower --------->4795451909
# 107 - El follower 4795451909 tiene 3310 seguidores
# Follower --------->266897100
# 108 - El follower 266897100 tiene 247 seguidores
# Follower --------->1419298866
# 109 - El follower 1419298866 tiene 707 seguidores
# Follower --------->728382570249981952
# 110 - El follower 728382570249981952 tiene 313 seguidores
# Follower --------->1103400885475004416
# 111 - El follower 1103400885475004416 tiene 90 seguidores
# Follower --------->288413387
# 112 - El follower 288413387 tiene 17 seguidores
# Follower --------->1186937974434553856
# 113 - El follower 1186937974434553856 tiene 175 seguidores
# Follower --------->1122988172969951233
# 114 - El follower 1122988172969951233 tiene 448 seguidores
# Follower --------->965711714108035073
# 115 - El follower 965711714108035073 tiene 679 seguidores
# Follower --------->1138539255163228160
# 116 - El follower 1138539255163228160 tiene 14 seguidores
# Follower --------->3375591226
# 117 - El follower 3375591226 tiene 948 seguidores
# Follower --------->1185965170029420544
# 118 - El follower 1185965170029420544 tiene 4 seguidores
# Follower --------->1189514475977805826
# 119 - El follower 1189514475977805826 tiene 26 seguidores
# Follower --------->1164895859936563200
# Rate limit reached. Sleeping for: 894
# 120 - El follower 1164895859936563200 tiene 142 seguidores
# Follower --------->589922921
# 121 - El follower 589922921 tiene 172 seguidores
# Follower --------->208757743
# 122 - El follower 208757743 tiene 63 seguidores
# Follower --------->469593822
# 123 - El usuario 469593822 no nos deja acceder a sus datos
# Follower --------->17972582
# 124 - El follower 17972582 tiene 312 seguidores
# Follower --------->150758393
# 125 - El follower 150758393 tiene 570 seguidores
# Follower --------->140349661
# 126 - El follower 140349661 tiene 56 seguidores
# Follower --------->2159632612
# 127 - El follower 2159632612 tiene 7 seguidores
# Follower --------->566556394
# 128 - El follower 566556394 tiene 211 seguidores
# Follower --------->49020441
# 129 - El follower 49020441 tiene 449 seguidores
# Follower --------->152188854
# 130 - El follower 152188854 tiene 271 seguidores
# Follower --------->986347244713664512
# 131 - El follower 986347244713664512 tiene 41 seguidores
# Follower --------->266206630
# 132 - El follower 266206630 tiene 205 seguidores
# Follower --------->4786360043
# 133 - El follower 4786360043 tiene 4183 seguidores
# Follower --------->260611316
# 134 - El follower 260611316 tiene 21 seguidores
# Follower --------->1174444865897345024
# Rate limit reached. Sleeping for: 894
# Failed to send request: ('Connection aborted.', OSError("(54, 'ECONNRESET')"))
# Follower --------->95217936
# 136 - El follower 95217936 tiene 10 seguidores
# Follower --------->619810936
# 137 - El usuario 619810936 no nos deja acceder a sus datos
# Follower --------->3003151337
# 138 - El follower 3003151337 tiene 1 seguidores
# Follower --------->1158930019009335296
# 139 - El follower 1158930019009335296 tiene 568 seguidores
# Follower --------->2417269134
# 140 - El follower 2417269134 tiene 213 seguidores
# Follower --------->1119980084440510465
# 141 - El follower 1119980084440510465 tiene 11 seguidores
# Follower --------->4866855484
# 142 - El follower 4866855484 tiene 721 seguidores
# Follower --------->1083448355349397504
# 143 - El follower 1083448355349397504 tiene 6188 seguidores
# Follower --------->495157183
# 144 - El follower 495157183 tiene 954 seguidores
# Follower --------->522343669
# 145 - El follower 522343669 tiene 27 seguidores
# Follower --------->269995742
# 146 - El follower 269995742 tiene 131 seguidores
# Follower --------->14456775
# 147 - El follower 14456775 tiene 124 seguidores
# Follower --------->1171482015641718788
# 148 - El follower 1171482015641718788 tiene 407 seguidores
# Follower --------->749461133111791616
# 149 - El follower 749461133111791616 tiene 250 seguidores
# Follower --------->49126592
# Rate limit reached. Sleeping for: 894
# 150 - El follower 49126592 tiene 114 seguidores
# Follower --------->292217941
# 151 - El follower 292217941 tiene 64 seguidores
# Follower --------->410633493
# 152 - El follower 410633493 tiene 152 seguidores
# Follower --------->1121705314473082880
# 153 - El follower 1121705314473082880 tiene 91 seguidores
# Follower --------->272628940
# 154 - El follower 272628940 tiene 187 seguidores
# Follower --------->789595098174685184
# 155 - El follower 789595098174685184 tiene 134 seguidores
# Follower --------->917711055937331205
# 156 - El follower 917711055937331205 tiene 141 seguidores
# Follower --------->96730899
# 157 - El follower 96730899 tiene 6396 seguidores
# Follower --------->324857822
# 158 - El follower 324857822 tiene 3023 seguidores
# Follower --------->1075468808108814338
# 159 - El follower 1075468808108814338 tiene 382 seguidores
# Follower --------->144801834
# 160 - El follower 144801834 tiene 1993 seguidores
# Follower --------->22947082
# 161 - El follower 22947082 tiene 987 seguidores
# Follower --------->188300159
# 162 - El follower 188300159 tiene 1917 seguidores
# Follower --------->972467273012260864
# 163 - El follower 972467273012260864 tiene 415 seguidores
# Follower --------->274592041
# Rate limit reached. Sleeping for: 894
# 164 - El follower 274592041 tiene 3836 seguidores
# Follower --------->2428806922
# 165 - El follower 2428806922 tiene 7665 seguidores
# Follower --------->75495576
# 166 - El follower 75495576 tiene 464 seguidores
# Follower --------->295100886
# 167 - El follower 295100886 tiene 191 seguidores
# Follower --------->1075910966
# Rate limit reached. Sleeping for: 893
# 168 - El follower 1075910966 tiene 57237 seguidores
# Follower --------->230418390
# 169 - El follower 230418390 tiene 633 seguidores
# Follower --------->235346355
# 170 - El follower 235346355 tiene 317 seguidores
# Follower --------->43210905
# 171 - El follower 43210905 tiene 2684 seguidores
# Follower --------->12339482
# 172 - El follower 12339482 tiene 1892 seguidores
# Follower --------->1379795863
# 173 - El follower 1379795863 tiene 3782 seguidores
# Follower --------->369247037
# 174 - El follower 369247037 tiene 1829 seguidores
# Follower --------->1098874382980730880
# 175 - El follower 1098874382980730880 tiene 140 seguidores
# Follower --------->385462306
# 176 - El follower 385462306 tiene 1394 seguidores
# Follower --------->883598688
# 177 - El follower 883598688 tiene 70 seguidores
# Follower --------->1922819430
# 178 - El follower 1922819430 tiene 773 seguidores
# Follower --------->1345030855
# 179 - El follower 1345030855 tiene 381 seguidores
# Follower --------->126602043
# 180 - El follower 126602043 tiene 3297 seguidores
# Follower --------->267078766
# 181 - El follower 267078766 tiene 673 seguidores
# Follower --------->536435650
# Rate limit reached. Sleeping for: 894
# 182 - El follower 536435650 tiene 239 seguidores
# Follower --------->2520691851
# 183 - El follower 2520691851 tiene 1291 seguidores
# Follower --------->1951680043
# 184 - El follower 1951680043 tiene 145 seguidores
# Follower --------->748930737307525120
# 185 - El follower 748930737307525120 tiene 662 seguidores
# Follower --------->1172470300979671040
# 186 - El follower 1172470300979671040 tiene 40 seguidores
# Follower --------->911168364923555840
# 187 - El follower 911168364923555840 tiene 66 seguidores
# Follower --------->1103759076692017152
# 188 - El follower 1103759076692017152 tiene 10 seguidores
# Follower --------->67359755
# 189 - El follower 67359755 tiene 42 seguidores
# Follower --------->882529980038750210
# 190 - El follower 882529980038750210 tiene 18 seguidores
# Follower --------->95485591
# 191 - El follower 95485591 tiene 170 seguidores
# Follower --------->1005220705
# 192 - El follower 1005220705 tiene 45 seguidores
# Follower --------->417095907
# 193 - El follower 417095907 tiene 959 seguidores
# Follower --------->769264026
# 194 - El follower 769264026 tiene 19 seguidores
# Follower --------->2802260702
# 195 - El follower 2802260702 tiene 262 seguidores
# Follower --------->604756193
# 196 - El usuario 604756193 no nos deja acceder a sus datos
# Follower --------->1110561380598538240
# Rate limit reached. Sleeping for: 894
# 197 - El follower 1110561380598538240 tiene 3 seguidores
# Follower --------->1157010722599161858
# 198 - El follower 1157010722599161858 tiene 4 seguidores
# Follower --------->856195997600501762
# 199 - El follower 856195997600501762 tiene 0 seguidores
# Follower --------->977352185435578368
# 200 - El follower 977352185435578368 tiene 50 seguidores
# Follower --------->423969547
# 201 - El usuario 423969547 no nos deja acceder a sus datos
# Follower --------->3384126153
# 202 - El follower 3384126153 tiene 104 seguidores
# Follower --------->2267192342
# 203 - El follower 2267192342 tiene 183 seguidores
# Follower --------->891216939443527680
# 204 - El follower 891216939443527680 tiene 78 seguidores
# Follower --------->1136907122900439043
# 205 - El follower 1136907122900439043 tiene 264 seguidores
# Follower --------->49231477
# 206 - El follower 49231477 tiene 235 seguidores
# Follower --------->106495340
# 207 - El follower 106495340 tiene 438 seguidores
# Follower --------->232341589
# 208 - El follower 232341589 tiene 100 seguidores
# Follower --------->206451237
# 209 - El follower 206451237 tiene 63 seguidores
# Follower --------->627670338
# 210 - El usuario 627670338 no nos deja acceder a sus datos
# Follower --------->52290247
# 211 - El follower 52290247 tiene 29 seguidores
# Follower --------->2550679345
# Rate limit reached. Sleeping for: 894
# 212 - El follower 2550679345 tiene 48 seguidores
# Follower --------->172859440
# 213 - El follower 172859440 tiene 59 seguidores
# Follower --------->1155897630830055431
# 214 - El follower 1155897630830055431 tiene 18 seguidores
# Follower --------->927474757003603968
# 215 - El follower 927474757003603968 tiene 2 seguidores
# Follower --------->2832195031
# 216 - El follower 2832195031 tiene 863 seguidores
# Follower --------->326264713
# 217 - El follower 326264713 tiene 680 seguidores
# Follower --------->918841282197426176
# 218 - El follower 918841282197426176 tiene 374 seguidores
# Follower --------->55351126
# 219 - El follower 55351126 tiene 639 seguidores
# Follower --------->261227398
# 220 - El follower 261227398 tiene 20 seguidores
# Follower --------->931009980
# 221 - El follower 931009980 tiene 17 seguidores
# Follower --------->776129038901473280
# 222 - El follower 776129038901473280 tiene 93 seguidores
# Follower --------->919705495933476865
# 223 - El follower 919705495933476865 tiene 50 seguidores
# Follower --------->1146799924455137281
# 224 - El follower 1146799924455137281 tiene 721 seguidores
# Follower --------->1033317343
# 225 - El usuario 1033317343 no nos deja acceder a sus datos
# Follower --------->920592878895796224
# 226 - El follower 920592878895796224 tiene 142 seguidores
# Follower --------->1139683732682657792
# Rate limit reached. Sleeping for: 894
# 227 - El follower 1139683732682657792 tiene 70 seguidores
# Follower --------->14260921
# 228 - El follower 14260921 tiene 88 seguidores
# Follower --------->253930986
# 229 - El follower 253930986 tiene 48 seguidores
# Follower --------->267397452
# 230 - El follower 267397452 tiene 173 seguidores
# Follower --------->211394459
# 231 - El follower 211394459 tiene 180 seguidores
# Follower --------->2701994590
# 232 - El follower 2701994590 tiene 698 seguidores
# Follower --------->220553332
# 233 - El follower 220553332 tiene 172 seguidores
# Follower --------->469414032
# 234 - El follower 469414032 tiene 6 seguidores
# Follower --------->4158797301
# 235 - El follower 4158797301 tiene 149 seguidores
# Follower --------->80175900
# 236 - El follower 80175900 tiene 420 seguidores
# Follower --------->102862880
# 237 - El follower 102862880 tiene 124 seguidores
# Follower --------->872117755
# 238 - El follower 872117755 tiene 580 seguidores
# Follower --------->1093302924313325570
# 239 - El follower 1093302924313325570 tiene 38 seguidores
# Follower --------->36495364
# 240 - El follower 36495364 tiene 2087 seguidores
# Follower --------->789291739
# 241 - El follower 789291739 tiene 441 seguidores
# Follower --------->3296651076
# Rate limit reached. Sleeping for: 892
# 242 - El follower 3296651076 tiene 40 seguidores
# Follower --------->1122917205857918977
# 243 - El follower 1122917205857918977 tiene 116 seguidores
# Follower --------->167116491
# 244 - El follower 167116491 tiene 42 seguidores
# Follower --------->900791472643084293
# 245 - El follower 900791472643084293 tiene 2244 seguidores
# Follower --------->2596552676
# 246 - El follower 2596552676 tiene 149 seguidores
# Follower --------->1055182915863281672
# 247 - El usuario 1055182915863281672 no nos deja acceder a sus datos
# Follower --------->1129342804344397825
# 248 - El follower 1129342804344397825 tiene 204 seguidores
# Follower --------->2775364786
# 249 - El follower 2775364786 tiene 27 seguidores
# Follower --------->4737947385
# 250 - El follower 4737947385 tiene 17 seguidores
# Follower --------->302772644
# 251 - El follower 302772644 tiene 111 seguidores
# Follower --------->2445525426
# 252 - El follower 2445525426 tiene 100 seguidores
# Follower --------->16947418
# 253 - El usuario 16947418 no nos deja acceder a sus datos
# Follower --------->1261295371
# 254 - El follower 1261295371 tiene 16 seguidores
# Follower --------->1099413063873245186
# 255 - El follower 1099413063873245186 tiene 0 seguidores
# Follower --------->134829365
# 256 - El usuario 134829365 no nos deja acceder a sus datos
# Follower --------->1062483629886988288
# Rate limit reached. Sleeping for: 894
# 257 - El follower 1062483629886988288 tiene 8605 seguidores
# Follower --------->303642532
# 258 - El usuario 303642532 no nos deja acceder a sus datos
# Follower --------->22681195
# 259 - El follower 22681195 tiene 77 seguidores
# Follower --------->962367276606423040
# 260 - El follower 962367276606423040 tiene 764 seguidores
# Follower --------->104745672
# 261 - El follower 104745672 tiene 110 seguidores
# Follower --------->383934253
# 262 - El follower 383934253 tiene 191 seguidores
# Follower --------->1715967223
# 263 - El follower 1715967223 tiene 388 seguidores
# Follower --------->318993513
# 264 - El follower 318993513 tiene 310 seguidores
# Follower --------->2317390682
# 265 - El follower 2317390682 tiene 893 seguidores
# Follower --------->924401311906451462
# 266 - El follower 924401311906451462 tiene 37 seguidores
# Follower --------->343382124
# 267 - El follower 343382124 tiene 10 seguidores
# Follower --------->1357992950
# 268 - El follower 1357992950 tiene 84 seguidores
# Follower --------->357163894
# 269 - El follower 357163894 tiene 418 seguidores
# Follower --------->99809517
# 270 - El follower 99809517 tiene 193 seguidores
# Follower --------->899808815910191104
# Rate limit reached. Sleeping for: 894
# Failed to send request: ('Connection aborted.', OSError("(54, 'ECONNRESET')"))
# Follower --------->134447383
# 272 - El follower 134447383 tiene 1873 seguidores
# Follower --------->1098972648128811014
# 273 - El follower 1098972648128811014 tiene 81 seguidores
# Follower --------->1112074444724416513
# 274 - El follower 1112074444724416513 tiene 1961 seguidores
# Follower --------->857616032189612032
# 275 - El follower 857616032189612032 tiene 512 seguidores
# Follower --------->1120187355128840193
# 276 - El follower 1120187355128840193 tiene 69 seguidores
# Follower --------->1120248078685044736
# 277 - El follower 1120248078685044736 tiene 0 seguidores
# Follower --------->795728197711261698
# 278 - El usuario 795728197711261698 no nos deja acceder a sus datos
# Follower --------->1283468348
# 279 - El follower 1283468348 tiene 339 seguidores
# Follower --------->1084777902380584960
# 280 - El follower 1084777902380584960 tiene 25 seguidores
# Follower --------->728823018
# 281 - El follower 728823018 tiene 10 seguidores
# Follower --------->1105031494282690561
# 282 - El follower 1105031494282690561 tiene 114 seguidores
# Follower --------->234272472
# 283 - El follower 234272472 tiene 380 seguidores
# Follower --------->334078686
# 284 - El follower 334078686 tiene 216 seguidores
# Follower --------->327476251
# 285 - El follower 327476251 tiene 2417 seguidores
# Follower --------->260469342
# 286 - El follower 260469342 tiene 663 seguidores
# Follower --------->778151873803067392
# Rate limit reached. Sleeping for: 895
# Failed to send request: ('Connection aborted.', OSError("(54, 'ECONNRESET')"))
# Follower --------->3299519009
# 288 - El follower 3299519009 tiene 1991 seguidores
# Follower --------->2360179226
# 289 - El usuario 2360179226 no nos deja acceder a sus datos
# Follower --------->61330962
# 290 - El follower 61330962 tiene 86 seguidores
# Follower --------->253939528
# 291 - El follower 253939528 tiene 271 seguidores
# Follower --------->415237850
# 292 - El follower 415237850 tiene 316 seguidores
# Follower --------->911773067671719936
# 293 - El follower 911773067671719936 tiene 11800 seguidores
# Follower --------->732831114201583617
# 294 - El follower 732831114201583617 tiene 177 seguidores
# Follower --------->2810290568
# 295 - El follower 2810290568 tiene 114 seguidores
# Follower --------->1905000438
# 296 - El follower 1905000438 tiene 1182 seguidores
# Follower --------->2458754380
# 297 - El follower 2458754380 tiene 210 seguidores
# Follower --------->217591820
# 298 - El follower 217591820 tiene 507 seguidores
# Follower --------->881986786502860801
# 299 - El follower 881986786502860801 tiene 1292 seguidores
# Follower --------->970019166559391745
# 300 - El follower 970019166559391745 tiene 22 seguidores
# Follower --------->636548071
# Rate limit reached. Sleeping for: 893
# 301 - El follower 636548071 tiene 1409 seguidores
# Follower --------->4879324121
# 302 - El follower 4879324121 tiene 140 seguidores
# Follower --------->2787431048
# 303 - El follower 2787431048 tiene 281 seguidores
# Follower --------->863604703
# 304 - El follower 863604703 tiene 6 seguidores
# Follower --------->199221680
# 305 - El follower 199221680 tiene 28 seguidores
# Follower --------->940911512599912448
# 306 - El follower 940911512599912448 tiene 160 seguidores
# Follower --------->1099986658387202051
# 307 - El follower 1099986658387202051 tiene 344 seguidores
# Follower --------->15596151
# 308 - El follower 15596151 tiene 4112 seguidores
# Follower --------->1109007074569216001
# 309 - El follower 1109007074569216001 tiene 36 seguidores
# Follower --------->825043520
# 310 - El follower 825043520 tiene 155 seguidores
# Follower --------->880285183
# 311 - El follower 880285183 tiene 26 seguidores
# Follower --------->979932248
# 312 - El usuario 979932248 no nos deja acceder a sus datos
# Follower --------->565605430
# 313 - El follower 565605430 tiene 31 seguidores
# Follower --------->856746497987268608
# 314 - El follower 856746497987268608 tiene 198 seguidores
# Follower --------->725372220583862279
# 315 - El follower 725372220583862279 tiene 38 seguidores
# Follower --------->1082751622797819906
# Rate limit reached. Sleeping for: 894
# 316 - El follower 1082751622797819906 tiene 34 seguidores
# Follower --------->797901439267913728
# 317 - El follower 797901439267913728 tiene 12 seguidores
# Follower --------->786588345585500160
# 318 - El follower 786588345585500160 tiene 2149 seguidores
# Follower --------->748390947759788032
# 319 - El follower 748390947759788032 tiene 11 seguidores
# Follower --------->727521538468118528
# 320 - El follower 727521538468118528 tiene 62 seguidores
# Follower --------->335296044
# 321 - El usuario 335296044 no nos deja acceder a sus datos
# Follower --------->919674252160372736
# 322 - El follower 919674252160372736 tiene 0 seguidores
# Follower --------->1055544750630191104
# 323 - El follower 1055544750630191104 tiene 40 seguidores
# Follower --------->1105466720838397952
# 324 - El follower 1105466720838397952 tiene 235 seguidores
# Follower --------->74294867
# 325 - El follower 74294867 tiene 32 seguidores
# Follower --------->17053937
# 326 - El follower 17053937 tiene 10069 seguidores
# Follower --------->386051947
# 327 - El follower 386051947 tiene 166 seguidores
# Follower --------->338259207
# 328 - El follower 338259207 tiene 2126 seguidores
# Follower --------->197467245
# Rate limit reached. Sleeping for: 894
# Failed to send request: ('Connection aborted.', OSError("(54, 'ECONNRESET')"))
# Follower --------->4850154322
# 330 - El follower 4850154322 tiene 42 seguidores
# Follower --------->2972907299
# 331 - El follower 2972907299 tiene 1335 seguidores
# Follower --------->181570574
# 332 - El usuario 181570574 no nos deja acceder a sus datos
# Follower --------->3344035072
# 333 - El follower 3344035072 tiene 8 seguidores
# Follower --------->439293707
# 334 - El follower 439293707 tiene 902 seguidores
# Follower --------->846351350
# 335 - El follower 846351350 tiene 27 seguidores
# Follower --------->3226938653
# 336 - El follower 3226938653 tiene 474 seguidores
# Follower --------->291894534
# 337 - El follower 291894534 tiene 71 seguidores
# Follower --------->82632187
# 338 - El follower 82632187 tiene 119 seguidores
# Follower --------->911363290642702339
# 339 - El follower 911363290642702339 tiene 54 seguidores
# Follower --------->3688337415
# 340 - El follower 3688337415 tiene 380 seguidores
# Follower --------->14135101
# 341 - El follower 14135101 tiene 18317 seguidores
# Follower --------->389688115
# Rate limit reached. Sleeping for: 894
# 342 - El follower 389688115 tiene 43 seguidores
# Follower --------->85976127
# 343 - El follower 85976127 tiene 1054 seguidores
# Follower --------->195841105
# 344 - El follower 195841105 tiene 199 seguidores
# Follower --------->1101836495391023110
# 345 - El follower 1101836495391023110 tiene 11 seguidores
# Follower --------->730224774987845638
# 346 - El follower 730224774987845638 tiene 18 seguidores
# Follower --------->1713153726
# 347 - El follower 1713153726 tiene 7 seguidores
# Follower --------->4850101264
# 348 - El follower 4850101264 tiene 61 seguidores
# Follower --------->122455228
# 349 - El follower 122455228 tiene 4244 seguidores
# Follower --------->17732795
# 350 - El follower 17732795 tiene 64 seguidores
# Follower --------->833077330360807425
# 351 - El follower 833077330360807425 tiene 2509 seguidores
# Follower --------->3010608918
# 352 - El follower 3010608918 tiene 266 seguidores
# Follower --------->1057561806477189120
# 353 - El follower 1057561806477189120 tiene 404 seguidores
# Follower --------->207957856
# 354 - El follower 207957856 tiene 1182 seguidores
# Follower --------->397216608
# 355 - El follower 397216608 tiene 3159 seguidores
# Follower --------->1037086252049334273
# 356 - El follower 1037086252049334273 tiene 309 seguidores
# Follower --------->217441025
# Rate limit reached. Sleeping for: 894
# Failed to send request: ('Connection aborted.', OSError("(60, 'ETIMEDOUT')"))
# Follower --------->2984485426
# 358 - El follower 2984485426 tiene 0 seguidores
# Follower --------->1065046646373920770
# 359 - El follower 1065046646373920770 tiene 99 seguidores
# Follower --------->4118905558
# 360 - El follower 4118905558 tiene 2438 seguidores
# Follower --------->306785937
# 361 - El follower 306785937 tiene 438 seguidores
# Follower --------->1438732669
# 362 - El follower 1438732669 tiene 10 seguidores
# Follower --------->137678406
# 363 - El follower 137678406 tiene 32525 seguidores
# Follower --------->1085722231278354432
# 364 - El follower 1085722231278354432 tiene 26 seguidores
# Follower --------->2344612990
# 365 - El follower 2344612990 tiene 7 seguidores
# Follower --------->1093410452237881344
# 366 - El follower 1093410452237881344 tiene 2 seguidores
# Follower --------->15837083
# Rate limit reached. Sleeping for: 893
# 367 - El follower 15837083 tiene 76 seguidores
# Follower --------->1071933176434622464
# 368 - El follower 1071933176434622464 tiene 86 seguidores
# Follower --------->1093180544236564482
# 369 - El follower 1093180544236564482 tiene 172 seguidores
# Follower --------->187342941
# 370 - El follower 187342941 tiene 98 seguidores
# Follower --------->508697101
# 371 - El follower 508697101 tiene 127 seguidores
# Follower --------->1033648956499222528
# 372 - El follower 1033648956499222528 tiene 1128 seguidores
# Follower --------->2434904682
# 373 - El follower 2434904682 tiene 94 seguidores
# Follower --------->1084771371329175552
# 374 - El follower 1084771371329175552 tiene 465 seguidores
# Follower --------->120605790
# 375 - El follower 120605790 tiene 285 seguidores
# Follower --------->137467666
# 376 - El follower 137467666 tiene 111 seguidores
# Follower --------->3295849528
# 377 - El follower 3295849528 tiene 197 seguidores
# Follower --------->977952164
# 378 - El follower 977952164 tiene 18 seguidores
# Follower --------->1062685860087414784
# 379 - El follower 1062685860087414784 tiene 48 seguidores
# Follower --------->17863599
# 380 - El follower 17863599 tiene 4862 seguidores
# Follower --------->913054949055090688
# 381 - El follower 913054949055090688 tiene 308 seguidores
# Follower --------->1488460416
# Rate limit reached. Sleeping for: 894
# 382 - El follower 1488460416 tiene 3202 seguidores
# Follower --------->873734975258062848
# 383 - El follower 873734975258062848 tiene 268 seguidores
# Follower --------->1279400059
# 384 - El follower 1279400059 tiene 31 seguidores
# Follower --------->4032131295
# 385 - El follower 4032131295 tiene 842 seguidores
# Follower --------->980846595737640965
# 386 - El follower 980846595737640965 tiene 408 seguidores
# Follower --------->474773670
# 387 - El follower 474773670 tiene 4465 seguidores
# Follower --------->1081581217462603778
# 388 - El follower 1081581217462603778 tiene 395 seguidores
# Follower --------->1039331765792456704
# 389 - El follower 1039331765792456704 tiene 84 seguidores
# Follower --------->192522831
# 390 - El follower 192522831 tiene 1419 seguidores
# Follower --------->1072598912832286721
# 391 - El follower 1072598912832286721 tiene 0 seguidores
# Follower --------->405804727
# 392 - El follower 405804727 tiene 525 seguidores
# Follower --------->939980077571420167
# 393 - El follower 939980077571420167 tiene 508 seguidores
# Follower --------->1355086945
# 394 - El follower 1355086945 tiene 7 seguidores
# Follower --------->249007164
# 395 - El follower 249007164 tiene 995 seguidores
# Follower --------->1064521106554568704
# 396 - El follower 1064521106554568704 tiene 132 seguidores
# Follower --------->1343876654
# Rate limit reached. Sleeping for: 894
# 397 - El follower 1343876654 tiene 91 seguidores
# Follower --------->1201937443
# 398 - El follower 1201937443 tiene 4874 seguidores
# Follower --------->2838287115
# 399 - El follower 2838287115 tiene 291 seguidores
# Follower --------->133551258
# 400 - El follower 133551258 tiene 157 seguidores
# Follower --------->3842288955
# 401 - El follower 3842288955 tiene 139 seguidores
# Follower --------->987734660267565056
# 402 - El follower 987734660267565056 tiene 845 seguidores
# Follower --------->12892032
# 403 - El follower 12892032 tiene 228 seguidores
# Follower --------->3665813129
# 404 - El follower 3665813129 tiene 199 seguidores
# Follower --------->217589494
# 405 - El follower 217589494 tiene 165 seguidores
# Follower --------->1078308789592444928
# 406 - El follower 1078308789592444928 tiene 92 seguidores
# Follower --------->1193595097
# 407 - El follower 1193595097 tiene 11587 seguidores
# Follower --------->75342656
# 408 - El follower 75342656 tiene 0 seguidores
# Follower --------->772119574833664000
# 409 - El usuario 772119574833664000 no nos deja acceder a sus datos
# Follower --------->775627917330186240
# Rate limit reached. Sleeping for: 894
# 410 - El usuario 775627917330186240 no nos deja acceder a sus datos
# Follower --------->1027178417844887552
# 411 - El follower 1027178417844887552 tiene 1 seguidores
# Follower --------->2347208693
# 412 - El follower 2347208693 tiene 679 seguidores
# Follower --------->3298765342
# 413 - El follower 3298765342 tiene 322 seguidores
# Follower --------->416238789
# 414 - El follower 416238789 tiene 961 seguidores
# Follower --------->1073670803869351939
# 415 - El follower 1073670803869351939 tiene 1 seguidores
# Follower --------->309617530
# 416 - El follower 309617530 tiene 1103 seguidores
# Follower --------->114516439
# 417 - El follower 114516439 tiene 281 seguidores
# Follower --------->3218859202
# 418 - El follower 3218859202 tiene 71 seguidores
# Follower --------->883437419693047808
# 419 - El follower 883437419693047808 tiene 209 seguidores
# Follower --------->227056307
# 420 - El follower 227056307 tiene 314 seguidores
# Follower --------->2952874306
# 421 - El follower 2952874306 tiene 23 seguidores
# Follower --------->2912528287
# 422 - El usuario 2912528287 no nos deja acceder a sus datos
# Follower --------->187653310
# 423 - El follower 187653310 tiene 152 seguidores
# Follower --------->86998264
# 424 - El follower 86998264 tiene 2091 seguidores
# Follower --------->82894804
# Rate limit reached. Sleeping for: 894
# 425 - El follower 82894804 tiene 1664 seguidores
# Follower --------->338500666
# 426 - El follower 338500666 tiene 322 seguidores
# Follower --------->132333002
# 427 - El follower 132333002 tiene 22 seguidores
# Follower --------->2955195436
# 428 - El follower 2955195436 tiene 1436 seguidores
# Follower --------->1355772038
# 429 - El follower 1355772038 tiene 6 seguidores
# Follower --------->792452013871300608
# 430 - El follower 792452013871300608 tiene 48 seguidores
# Follower --------->1064107576349130752
# 431 - El follower 1064107576349130752 tiene 366 seguidores
# Follower --------->2824948678
# 432 - El follower 2824948678 tiene 70 seguidores
# Follower --------->821439972645498883
# 433 - El follower 821439972645498883 tiene 111 seguidores
# Follower --------->89283858
# 434 - El follower 89283858 tiene 20147 seguidores
# Follower --------->980236683852636160
# 435 - El follower 980236683852636160 tiene 163 seguidores
# Follower --------->498141500
# Rate limit reached. Sleeping for: 893
# Failed to send request: ('Connection aborted.', OSError("(60, 'ETIMEDOUT')"))
# Follower --------->2707431362
# Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/followers/ids.json?id=2707431362&cursor=-1 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7feff7da93d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Follower --------->132851687
# Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/followers/ids.json?id=132851687&cursor=-1 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7feff7da9550>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Follower --------->155089809
# Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/followers/ids.json?id=155089809&cursor=-1 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7feff75321d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Follower --------->962774296916570112
# Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/followers/ids.json?id=962774296916570112&cursor=-1 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7feff814b990>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Follower --------->728143654636822530
# 441 - El follower 728143654636822530 tiene 648 seguidores
# Follower --------->971796017543897088
# 442 - El follower 971796017543897088 tiene 297 seguidores
# Follower --------->2844374418
# 443 - El follower 2844374418 tiene 63 seguidores
# Follower --------->95082328
# 444 - El usuario 95082328 no nos deja acceder a sus datos
# Follower --------->1057017067331862528
# 445 - El follower 1057017067331862528 tiene 24 seguidores
# Follower --------->1058871466220052481
# 446 - El follower 1058871466220052481 tiene 0 seguidores
# Follower --------->722878931943235584
# 447 - El usuario 722878931943235584 no nos deja acceder a sus datos
# Follower --------->762319792695042048
# 448 - El usuario 762319792695042048 no nos deja acceder a sus datos
# Follower --------->236948620
# 449 - El follower 236948620 tiene 776 seguidores
# Follower --------->405873374
# 450 - El usuario 405873374 no nos deja acceder a sus datos
# Follower --------->992245872569143296
# 451 - El follower 992245872569143296 tiene 245 seguidores
# Follower --------->1060603082940313600
# 452 - El follower 1060603082940313600 tiene 2 seguidores
# Follower --------->214032261
# 453 - El follower 214032261 tiene 4523 seguidores
# Follower --------->1620461760
# 454 - El follower 1620461760 tiene 830 seguidores
# Follower --------->1680276368
# Rate limit reached. Sleeping for: 429
# 455 - El usuario 1680276368 no nos deja acceder a sus datos
# Follower --------->3403757997
# 456 - El follower 3403757997 tiene 53 seguidores
# Follower --------->931823923
# 457 - El follower 931823923 tiene 16 seguidores
# Follower --------->760800617485008896
# 458 - El follower 760800617485008896 tiene 750 seguidores
# Follower --------->742332951766130688
# 459 - El follower 742332951766130688 tiene 727 seguidores
# Follower --------->501017681
# 460 - El follower 501017681 tiene 8304 seguidores
# Follower --------->888201341583196160
# 461 - El follower 888201341583196160 tiene 100 seguidores
# Follower --------->166660272
# 462 - El follower 166660272 tiene 16073 seguidores
# Follower --------->270079528
# 463 - El follower 270079528 tiene 43 seguidores
# Follower --------->1286558558
# 464 - El follower 1286558558 tiene 1529 seguidores
# Follower --------->159543688
# 465 - El usuario 159543688 no nos deja acceder a sus datos
# Follower --------->2153573971
# Rate limit reached. Sleeping for: 886
# 466 - El follower 2153573971 tiene 5 seguidores
# Follower --------->346911652
# 467 - El follower 346911652 tiene 161 seguidores
# Follower --------->302702997
# 468 - El follower 302702997 tiene 29 seguidores
# Follower --------->829957221673029633
# 469 - El follower 829957221673029633 tiene 77 seguidores
# Follower --------->501593883
# 470 - El follower 501593883 tiene 70 seguidores
# Follower --------->3074246214
# 471 - El follower 3074246214 tiene 10 seguidores
# Follower --------->3028533922
# 472 - El follower 3028533922 tiene 1172 seguidores
# Follower --------->53765207
# 473 - El follower 53765207 tiene 574 seguidores
# Follower --------->998282257097019392
# 474 - El follower 998282257097019392 tiene 1114 seguidores
# Follower --------->134752238
# 475 - El follower 134752238 tiene 75 seguidores
# Follower --------->40682496
# 476 - El follower 40682496 tiene 55 seguidores
# Follower --------->1042493594362368001
# 477 - El follower 1042493594362368001 tiene 729 seguidores
# Follower --------->2758681690
# Rate limit reached. Sleeping for: 885
# 478 - El follower 2758681690 tiene 82472 seguidores
# Follower --------->147623875
# 479 - El follower 147623875 tiene 65 seguidores
# Follower --------->822979828525727745
# Rate limit reached. Sleeping for: 883
# Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Read timed out. (read timeout=60)
# Follower --------->1299894949
# Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/followers/ids.json?id=1299894949&cursor=-1 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7feff7fd4950>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Follower --------->245829098
# Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/followers/ids.json?id=245829098&cursor=-1 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7feff7d8cb10>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Follower --------->59091469
# Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/followers/ids.json?id=59091469&cursor=-1 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7feff7534390>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Follower --------->88478189
# Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/followers/ids.json?id=88478189&cursor=-1 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7feff7da9f50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Follower --------->2849579134
# 485 - El follower 2849579134 tiene 13 seguidores
# Follower --------->21246129
# 486 - El follower 21246129 tiene 1 seguidores
# Follower --------->2930672915
# 487 - El follower 2930672915 tiene 259 seguidores
# Follower --------->66152031
# 488 - El follower 66152031 tiene 3187 seguidores
# Follower --------->212202239
# 489 - El follower 212202239 tiene 0 seguidores
# Follower --------->153900004
# 490 - El follower 153900004 tiene 407 seguidores
# Follower --------->2425863594
# 491 - El follower 2425863594 tiene 10 seguidores
# Follower --------->311096609
# 492 - El follower 311096609 tiene 308 seguidores
# Follower --------->338183663
# 493 - El follower 338183663 tiene 305 seguidores
# Follower --------->4217524895
# 494 - El follower 4217524895 tiene 29 seguidores
# Follower --------->1851537871
# 495 - El follower 1851537871 tiene 275 seguidores
# Follower --------->770637060713619456
# 496 - El follower 770637060713619456 tiene 1285 seguidores
# Follower --------->946270217851756545
# 497 - El follower 946270217851756545 tiene 294 seguidores
# Follower --------->875343013
# 498 - El follower 875343013 tiene 36 seguidores
# Follower --------->254179441
# 499 - El follower 254179441 tiene 11 seguidores
# Follower --------->985196746950299649
# Rate limit reached. Sleeping for: 887
# 500 - El follower 985196746950299649 tiene 170 seguidores
# Follower --------->846907875423404032
# 501 - El follower 846907875423404032 tiene 222 seguidores
# Follower --------->876784384703115264
# 502 - El follower 876784384703115264 tiene 151 seguidores
# Follower --------->17283179
# 503 - El follower 17283179 tiene 1055 seguidores
# Follower --------->361534233
# 504 - El follower 361534233 tiene 275 seguidores
# Follower --------->1630407859
# 505 - El follower 1630407859 tiene 39 seguidores
# Follower --------->778528320
# 506 - El follower 778528320 tiene 15 seguidores
# Follower --------->486853972
# 507 - El usuario 486853972 no nos deja acceder a sus datos
# Follower --------->2839111439
# 508 - El follower 2839111439 tiene 94 seguidores
# Follower --------->313606237
# 509 - El follower 313606237 tiene 14 seguidores
# Follower --------->824234931681394688
# 510 - El usuario 824234931681394688 no nos deja acceder a sus datos
# Follower --------->974784707098529792
# 511 - El follower 974784707098529792 tiene 1169 seguidores
# Follower --------->928456461180686338
# 512 - El follower 928456461180686338 tiene 33 seguidores
# Follower --------->2268654205
# 513 - El follower 2268654205 tiene 303 seguidores
# Follower --------->312087868
# 514 - El usuario 312087868 no nos deja acceder a sus datos
# Follower --------->321786509
# Rate limit reached. Sleeping for: 888
# Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Read timed out. (read timeout=60)
# Follower --------->847474554712711168
# 516 - El follower 847474554712711168 tiene 82 seguidores
# Follower --------->4254567554
# 517 - El follower 4254567554 tiene 452 seguidores
# Follower --------->629722660
# 518 - El follower 629722660 tiene 78 seguidores
# Follower --------->18585064
# 519 - El follower 18585064 tiene 339 seguidores
# Follower --------->2644025974
# 520 - El follower 2644025974 tiene 41 seguidores
# Follower --------->2387687005
# 521 - El follower 2387687005 tiene 75 seguidores
# Follower --------->444569080
# 522 - El follower 444569080 tiene 4890 seguidores
# Follower --------->503585923
# 523 - El follower 503585923 tiene 62 seguidores
# Follower --------->772728159338917888
# 524 - El follower 772728159338917888 tiene 81 seguidores
# Follower --------->65629661
# 525 - El usuario 65629661 no nos deja acceder a sus datos
# Follower --------->129851094
# 526 - El follower 129851094 tiene 174 seguidores
# Follower --------->250405612
# 527 - El follower 250405612 tiene 455 seguidores
# Follower --------->143078777
# 528 - El follower 143078777 tiene 594 seguidores
# Follower --------->2934106375
# 529 - El usuario 2934106375 no nos deja acceder a sus datos
# Follower --------->788111524858568704
# 530 - El follower 788111524858568704 tiene 0 seguidores
# Follower --------->4031559133
# Rate limit reached. Sleeping for: 887
# 531 - El usuario 4031559133 no nos deja acceder a sus datos
# Follower --------->92531108
# 532 - El follower 92531108 tiene 11 seguidores
# Follower --------->478294829
# 533 - El follower 478294829 tiene 12 seguidores
# Follower --------->274617138
# 534 - El follower 274617138 tiene 445 seguidores
# Follower --------->275210909
# 535 - El follower 275210909 tiene 70 seguidores
# Follower --------->877095327223996416
# 536 - El follower 877095327223996416 tiene 19 seguidores
# Follower --------->989063436733730816
# 537 - El follower 989063436733730816 tiene 294 seguidores
# Follower --------->980672549427208192
# 538 - El follower 980672549427208192 tiene 2 seguidores
# Follower --------->359934608
# 539 - El follower 359934608 tiene 354 seguidores
# Follower --------->1000303340209823745
# 540 - El follower 1000303340209823745 tiene 1477 seguidores
# Follower --------->3073746006
# 541 - El follower 3073746006 tiene 4 seguidores
# Follower --------->2885633817
# 542 - El follower 2885633817 tiene 42 seguidores
# Follower --------->141696758
# 543 - El usuario 141696758 no nos deja acceder a sus datos
# Follower --------->81739441
# 544 - El follower 81739441 tiene 319 seguidores
# Follower --------->334076268
# 545 - El follower 334076268 tiene 120 seguidores
# Follower --------->83629804
# Rate limit reached. Sleeping for: 888
# 546 - El follower 83629804 tiene 1085 seguidores
# Follower --------->15286966
# 547 - El follower 15286966 tiene 153 seguidores
# Follower --------->433389093
# 548 - El follower 433389093 tiene 20 seguidores
# Follower --------->1004726897203392512
# 549 - El follower 1004726897203392512 tiene 401 seguidores
# Follower --------->95532625
# 550 - El follower 95532625 tiene 377 seguidores
# Follower --------->32333402
# 551 - El follower 32333402 tiene 224 seguidores
# Follower --------->1308323742
# 552 - El follower 1308323742 tiene 29 seguidores
# Follower --------->384928466
# 553 - El follower 384928466 tiene 1253 seguidores
# Follower --------->290143710
# 554 - El usuario 290143710 no nos deja acceder a sus datos
# Follower --------->937592982
# 555 - El follower 937592982 tiene 4514 seguidores
# Follower --------->976902682224091136
# 556 - El follower 976902682224091136 tiene 16 seguidores
# Follower --------->4834855665
# 557 - El follower 4834855665 tiene 1534 seguidores
# Follower --------->796020377076060160
# 558 - El follower 796020377076060160 tiene 758 seguidores
# Follower --------->232391945
# 559 - El usuario 232391945 no nos deja acceder a sus datos
# Follower --------->1004700454775934977
# 560 - El follower 1004700454775934977 tiene 2 seguidores
# Follower --------->210938172
# Rate limit reached. Sleeping for: 887
# Failed to send request: ('Connection aborted.', OSError("(60, 'ETIMEDOUT')"))
# Follower --------->52102005
# Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/followers/ids.json?id=52102005&cursor=-1 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7feff8155710>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Follower --------->94826884
# 563 - El follower 94826884 tiene 211 seguidores
# Follower --------->618005197
# 564 - El follower 618005197 tiene 119 seguidores
# Follower --------->245928972
# 565 - El usuario 245928972 no nos deja acceder a sus datos
# Follower --------->1001404746228551680
# 566 - El follower 1001404746228551680 tiene 5 seguidores
# Follower --------->144265252
# 567 - El follower 144265252 tiene 211 seguidores
# Follower --------->621432690
# 568 - El follower 621432690 tiene 160 seguidores
# Follower --------->4785852635
# 569 - El follower 4785852635 tiene 2824 seguidores
# Follower --------->706014493852246016
# 570 - El follower 706014493852246016 tiene 415 seguidores
# Follower --------->558804431
# 571 - El follower 558804431 tiene 84 seguidores
# Follower --------->997141631106199553
# 572 - El follower 997141631106199553 tiene 14 seguidores
# Follower --------->293870784
# 573 - El follower 293870784 tiene 4 seguidores
# Follower --------->59905563
# 574 - El follower 59905563 tiene 19 seguidores
# Follower --------->59133365
# 575 - El follower 59133365 tiene 603 seguidores
# Follower --------->597568722
# 576 - El follower 597568722 tiene 1803 seguidores
# Follower --------->138330745
# Rate limit reached. Sleeping for: 694
# 577 - El follower 138330745 tiene 517 seguidores
# Follower --------->359051825
# 578 - El follower 359051825 tiene 5 seguidores
# Follower --------->358336449
# 579 - El follower 358336449 tiene 52 seguidores
# Follower --------->4333257561
# 580 - El follower 4333257561 tiene 142 seguidores
# Follower --------->196539787
# 581 - El follower 196539787 tiene 861 seguidores
# Follower --------->307927812
# 582 - El follower 307927812 tiene 137 seguidores
# Follower --------->4296501561
# 583 - El follower 4296501561 tiene 7 seguidores
# Follower --------->143445538
# 584 - El follower 143445538 tiene 707 seguidores
# Follower --------->783250530
# 585 - El follower 783250530 tiene 136 seguidores
# Follower --------->1637804689
# 586 - El follower 1637804689 tiene 42 seguidores
# Follower --------->4920782152
# 587 - El follower 4920782152 tiene 36 seguidores
# Follower --------->249070567
# 588 - El follower 249070567 tiene 89 seguidores
# Follower --------->163791630
# 589 - El follower 163791630 tiene 247 seguidores
# Follower --------->103857002
# 590 - El follower 103857002 tiene 63 seguidores
# Follower --------->1048477987
# 591 - El follower 1048477987 tiene 416 seguidores
# Follower --------->980999017
# Rate limit reached. Sleeping for: 887
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-b09123eaf124> in <module>
#      18         #como tengo 2600 seguidores y los puedo consultar 1, cuesta casi dos dias tener los seguidores de mis followers
#      19         n+=1
# ---> 20         for followers_hijo in tweepy.Cursor(api.followers_ids,follower_id).items():
#      21             followers_d[follower_id].append(followers_hijo)
#      22
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tweepy/cursor.py in __next__(self)
#      45
#      46     def __next__(self):
# ---> 47         return self.next()
#      48
#      49     def next(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tweepy/cursor.py in next(self)
#     193         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     194             # Reached end of current page, get the next page...
# --> 195             self.current_page = self.page_iterator.next()
#     196             self.page_index = -1
#     197         self.page_index += 1
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tweepy/cursor.py in next(self)
#      71         data, cursors = self.method(cursor=self.next_cursor,
#      72                                     *self.args,
# ---> 73                                     **self.kargs)
#      74         self.prev_cursor, self.next_cursor = cursors
#      75         if len(data) == 0:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     248                 return method
#     249             else:
# --> 250                 return method.execute()
#     251         finally:
#     252             method.session.close()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tweepy/binder.py in execute(self)
#     160                                     if self.wait_on_rate_limit_notify:
#     161                                         log.warning("Rate limit reached. Sleeping for: %d" % sleep_time)
# --> 162                                     time.sleep(sleep_time + 5)  # sleep for few extra sec
#     163
#     164                 # if self.wait_on_rate_limit and self._reset_time is not None and \
#
# KeyboardInterrupt:

# %%
#error: "Failed to send request: ('Connection aborted.', OSError("(54, 'ECONNRESET')"))"
print(len(followers_d))
# Out:
# 592

# %%
datos = []
for user_id in followers_d:
    for follower_id in followers_d[user_id]:
        enlace={'orig':user_id,
               'dest':follower_id}
        datos.append(enlace)
        #print(user_id,follower_id)

# %%
import pandas as pd
df = pd.DataFrame(datos)

# %%
#guardo los datos que tanto me ha costado obtener
#solo he llegado a 592 followers de los 2602 que tengo
df.info()
df.to_csv('grafo_followers.csv',sep=' ',index=False,header=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 564724 entries, 0 to 564723
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   orig    564724 non-null  int64
#  1   dest    564724 non-null  int64
# dtypes: int64(2)
# memory usage: 8.6 MB

# %%
friends_d = {}
n = 0 #consultas a la api 

for friend_id in friends:
    if friend_id in friends_d:
        print(f'El usuario {friend_id} ya se ha descargado')
        continue
        
    print(f'Friend --------->{friend_id}')
    friends_d[friend_id] = [] #lista de amigos de mis friends
    
    try:
        #friends_hijo=api.friends_ids(friend_id)
        #friends_ids da un máximo de 5000, si hay más, debo usar Cursor y hacer peticiones
        n+=1
        for friends_hijo in tweepy.Cursor(api.friends_ids,friend_id).items(300000):
            friends_d[friend_id].append(friends_hijo)
            
        print(f'{n} - El friend {friend_id} tiene {len(friends_d[friend_id])} friends')
    except tweepy.TweepError as e:
        if 'Not authorized' in str(e):
            print(f'{n} - El usuario {friend_id} no nos deja acceder a sus datos')
        else:
            print(e)
            time.sleep(60)
# Out:
# Friend --------->1138115772
# 1 - El friend 1138115772 tiene 175 friends
# Friend --------->120035961
# 2 - El friend 120035961 tiene 892 friends
# Friend --------->1263719931989934081
# 3 - El friend 1263719931989934081 tiene 133 friends
# Friend --------->1835275232
# 4 - El friend 1835275232 tiene 3217 friends
# Friend --------->861041185
# 5 - El friend 861041185 tiene 904 friends
# Friend --------->16265631
# 6 - El friend 16265631 tiene 2929 friends
# Friend --------->3514624529
# 7 - El friend 3514624529 tiene 738 friends
# Friend --------->243809723
# 8 - El friend 243809723 tiene 43 friends
# Friend --------->795938924489281536
# 9 - El friend 795938924489281536 tiene 883 friends
# Friend --------->144978689
# 10 - El friend 144978689 tiene 735 friends
# Friend --------->4284937761
# 11 - El friend 4284937761 tiene 1083 friends
# Friend --------->3147562362
# 12 - El friend 3147562362 tiene 1964 friends
# Friend --------->18189612
# 13 - El friend 18189612 tiene 245 friends
# Friend --------->1124651777436127234
# 14 - El friend 1124651777436127234 tiene 99 friends
# Friend --------->1967601206
# 15 - El friend 1967601206 tiene 175 friends
# Friend --------->719734080
# Rate limit reached. Sleeping for: 887
# 16 - El friend 719734080 tiene 1628 friends
# Friend --------->2201322068
# 17 - El friend 2201322068 tiene 1327 friends
# Friend --------->986502047251001345
# 18 - El friend 986502047251001345 tiene 161 friends
# Friend --------->879717595
# 19 - El friend 879717595 tiene 302 friends
# Friend --------->1305940272
# Rate limit reached. Sleeping for: 882
# Rate limit reached. Sleeping for: 882
# 20 - El friend 1305940272 tiene 145975 friends
# Friend --------->747148160
# 21 - El friend 747148160 tiene 2094 friends
# Friend --------->140104363
# 22 - El friend 140104363 tiene 101 friends
# Friend --------->1689053928
# 23 - El friend 1689053928 tiene 72 friends
# Friend --------->2264518987
# 24 - El friend 2264518987 tiene 191 friends
# Friend --------->2179172744
# 25 - El friend 2179172744 tiene 2197 friends
# Friend --------->1249383859143262210
# 26 - El friend 1249383859143262210 tiene 1 friends
# Friend --------->2887837801
# 27 - El friend 2887837801 tiene 0 friends
# Friend --------->855377879512883200
# 28 - El friend 855377879512883200 tiene 175 friends
# Friend --------->47927725
# 29 - El friend 47927725 tiene 2963 friends
# Friend --------->1242160584101187585
# 30 - El friend 1242160584101187585 tiene 30 friends
# Friend --------->1242045639170625537
# 31 - El friend 1242045639170625537 tiene 1305 friends
# Friend --------->2887051857
# Rate limit reached. Sleeping for: 885
# 32 - El friend 2887051857 tiene 172 friends
# Friend --------->904641871061897217
# 33 - El friend 904641871061897217 tiene 1542 friends
# Friend --------->326845755
# 34 - El friend 326845755 tiene 110 friends
# Friend --------->1244564729206640640
# 35 - El friend 1244564729206640640 tiene 195 friends
# Friend --------->3319318173
# 36 - El friend 3319318173 tiene 3099 friends
# Friend --------->269934544
# 37 - El friend 269934544 tiene 1052 friends
# Friend --------->1435875715
# 38 - El friend 1435875715 tiene 457 friends
# Friend --------->1240990552486752260
# 39 - El friend 1240990552486752260 tiene 28 friends
# Friend --------->2827884100
# 40 - El friend 2827884100 tiene 19 friends
# Friend --------->552951614
# 41 - El friend 552951614 tiene 351 friends
# Friend --------->103879980
# 42 - El friend 103879980 tiene 1565 friends
# Friend --------->44320986
# 43 - El friend 44320986 tiene 152 friends
# Friend --------->6319662
# 44 - El friend 6319662 tiene 1445 friends
# Friend --------->15106711
# 45 - El friend 15106711 tiene 602 friends
# Friend --------->17130131
# 46 - El friend 17130131 tiene 417 friends
# Friend --------->93881212
# Rate limit reached. Sleeping for: 886
# 47 - El friend 93881212 tiene 242 friends
# Friend --------->760751633051549701
# 48 - El friend 760751633051549701 tiene 4796 friends
# Friend --------->1242800864005443584
# 49 - El friend 1242800864005443584 tiene 52 friends
# Friend --------->1704888583
# 50 - El friend 1704888583 tiene 1146 friends
# Friend --------->1241508586238488577
# 51 - El friend 1241508586238488577 tiene 78 friends
# Friend --------->974998462101106688
# 52 - El friend 974998462101106688 tiene 479 friends
# Friend --------->148375390
# 53 - El friend 148375390 tiene 1583 friends
# Friend --------->458591807
# 54 - El friend 458591807 tiene 1199 friends
# Friend --------->740181123720982528
# 55 - El friend 740181123720982528 tiene 251 friends
# Friend --------->191416245
# 56 - El friend 191416245 tiene 370 friends
# Friend --------->1239513083141332992
# 57 - El friend 1239513083141332992 tiene 9 friends
# Friend --------->1086733250498908160
# 58 - El friend 1086733250498908160 tiene 640 friends
# Friend --------->519744095
# 59 - El friend 519744095 tiene 1959 friends
# Friend --------->215197653
# 60 - El friend 215197653 tiene 725 friends
# Friend --------->29975474
# 61 - El friend 29975474 tiene 1264 friends
# Friend --------->176371908
# Rate limit reached. Sleeping for: 887
# Failed to send request: ('Connection aborted.', OSError("(60, 'ETIMEDOUT')"))
# Friend --------->11364222
# Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/friends/ids.json?id=11364222&cursor=-1 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7feff7fd42d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Friend --------->1239297108278214656
# Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/friends/ids.json?id=1239297108278214656&cursor=-1 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fefe59f5e90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Friend --------->1239377521050869761
# Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/friends/ids.json?id=1239377521050869761&cursor=-1 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7feff7f8b6d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Friend --------->2739826012
# Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/friends/ids.json?id=2739826012&cursor=-1 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7feff7dc8710>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Friend --------->228794947
# 67 - El friend 228794947 tiene 7 friends
# Friend --------->501617939
# 68 - El friend 501617939 tiene 794 friends
# Friend --------->292019298
# 69 - El friend 292019298 tiene 1344 friends
# Friend --------->1238426683637731329
# 70 - El friend 1238426683637731329 tiene 19 friends
# Friend --------->58417540
# 71 - El friend 58417540 tiene 183 friends
# Friend --------->343327901
# 72 - El friend 343327901 tiene 44 friends
# Friend --------->112699467
# 73 - El friend 112699467 tiene 1160 friends
# Friend --------->267469345
# 74 - El friend 267469345 tiene 653 friends
# Friend --------->2821179496
# 75 - El friend 2821179496 tiene 6 friends
# Friend --------->196572692
# 76 - El friend 196572692 tiene 753 friends
# Friend --------->121505360
# 77 - El friend 121505360 tiene 95 friends
# Friend --------->306414975
# 78 - El friend 306414975 tiene 1070 friends
# Friend --------->264162413
# 79 - El friend 264162413 tiene 581 friends
# Friend --------->1229404364084826112
# 80 - El friend 1229404364084826112 tiene 0 friends
# Friend --------->1577955133
# Rate limit reached. Sleeping for: 420
# 81 - El friend 1577955133 tiene 4 friends
# Friend --------->1419298866
# 82 - El friend 1419298866 tiene 2965 friends
# Friend --------->853636220697669632
# 83 - El friend 853636220697669632 tiene 378 friends
# Friend --------->308451924
# 84 - El friend 308451924 tiene 1282 friends
# Friend --------->870541
# 85 - El friend 870541 tiene 839 friends
# Friend --------->261370194
# 86 - El friend 261370194 tiene 451 friends
# Friend --------->117382671
# 87 - El friend 117382671 tiene 3035 friends
# Friend --------->1226064262709334016
# 88 - El friend 1226064262709334016 tiene 390 friends
# Friend --------->864804906317819904
# 89 - El friend 864804906317819904 tiene 232 friends
# Friend --------->791198196
# 90 - El friend 791198196 tiene 1000 friends
# Friend --------->314837790
# 91 - El friend 314837790 tiene 1195 friends
# Friend --------->2831441229
# 92 - El friend 2831441229 tiene 175 friends
# Friend --------->1205464890158338049
# 93 - El friend 1205464890158338049 tiene 120 friends
# Friend --------->79200974
# 94 - El friend 79200974 tiene 1644 friends
# Friend --------->3017664915
# 95 - El friend 3017664915 tiene 1259 friends
# Friend --------->1217523182023905281
# Rate limit reached. Sleeping for: 887
# 96 - El friend 1217523182023905281 tiene 37 friends
# Friend --------->188669876
# 97 - El friend 188669876 tiene 1247 friends
# Friend --------->58459892
# 98 - El friend 58459892 tiene 428 friends
# Friend --------->377529981
# 99 - El friend 377529981 tiene 595 friends
# Friend --------->1139636315031404545
# 100 - El friend 1139636315031404545 tiene 115 friends
# Friend --------->1222812088407674881
# 101 - El friend 1222812088407674881 tiene 585 friends
# Friend --------->254308275
# 102 - El friend 254308275 tiene 2693 friends
# Friend --------->1220356864417943554
# 103 - El friend 1220356864417943554 tiene 482 friends
# Friend --------->732831114201583617
# 104 - El friend 732831114201583617 tiene 132 friends
# Friend --------->2154857881
# 105 - El friend 2154857881 tiene 96 friends
# Friend --------->1171482015641718788
# 106 - El friend 1171482015641718788 tiene 2054 friends
# Friend --------->1155310946
# 107 - El friend 1155310946 tiene 2692 friends
# Friend --------->1108494962885382144
# 108 - El friend 1108494962885382144 tiene 249 friends
# Friend --------->1204853272583892992
# 109 - El friend 1204853272583892992 tiene 30 friends
# Friend --------->756872080696676353
# 110 - El friend 756872080696676353 tiene 341 friends
# Friend --------->2313251690
# Rate limit reached. Sleeping for: 887
# 111 - El friend 2313251690 tiene 4487 friends
# Friend --------->906091255997837312
# 112 - El friend 906091255997837312 tiene 2478 friends
# Friend --------->414705452
# 113 - El friend 414705452 tiene 979 friends
# Friend --------->754617844227305472
# 114 - El friend 754617844227305472 tiene 515 friends
# Friend --------->919271583113498624
# 115 - El friend 919271583113498624 tiene 529 friends
# Friend --------->2820347818
# 116 - El friend 2820347818 tiene 156 friends
# Friend --------->11514162
# 117 - El friend 11514162 tiene 36 friends
# Friend --------->1920151681
# 118 - El friend 1920151681 tiene 948 friends
# Friend --------->1207294479893446656
# 119 - El friend 1207294479893446656 tiene 19 friends
# Friend --------->1042453416247681024
# 120 - El friend 1042453416247681024 tiene 496 friends
# Friend --------->953283520444715008
# 121 - El friend 953283520444715008 tiene 428 friends
# Friend --------->3262775438
# 122 - El friend 3262775438 tiene 85 friends
# Friend --------->1019665227439394817
# 123 - El friend 1019665227439394817 tiene 24 friends
# Friend --------->138996456
# 124 - El friend 138996456 tiene 2963 friends
# Friend --------->64677085
# 125 - El friend 64677085 tiene 131 friends
# Friend --------->1142076991455289351
# Rate limit reached. Sleeping for: 887
# Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Read timed out. (read timeout=60)
# Friend --------->1170802004655894528
# Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/friends/ids.json?id=1170802004655894528&cursor=-1 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fefeea92d90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Friend --------->3131611413
# Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/friends/ids.json?id=3131611413&cursor=-1 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fefe5a3afd0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Friend --------->4600040954
# Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/friends/ids.json?id=4600040954&cursor=-1 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fefe4e6ad90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Friend --------->1058704856016400384
# Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/friends/ids.json?id=1058704856016400384&cursor=-1 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7feff7dc80d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Friend --------->403871494
# 131 - El friend 403871494 tiene 522 friends
# Friend --------->2439889542
# 132 - El friend 2439889542 tiene 69 friends
# Friend --------->126148900
# 133 - El friend 126148900 tiene 7370 friends
# Friend --------->835865257088274432
# 134 - El friend 835865257088274432 tiene 2377 friends
# Friend --------->794476344474292224
# 135 - El friend 794476344474292224 tiene 98 friends
# Friend --------->394658061
# 136 - El friend 394658061 tiene 46 friends
# Friend --------->903501683350585344
# 137 - El friend 903501683350585344 tiene 246 friends
# Friend --------->2995106374
# 138 - El friend 2995106374 tiene 9 friends
# Friend --------->583771842
# 139 - El friend 583771842 tiene 236 friends
# Friend --------->775356633027321857
# 140 - El friend 775356633027321857 tiene 1352 friends
# Friend --------->2342103729
# 141 - El friend 2342103729 tiene 1379 friends
# Friend --------->3233705999
# 142 - El friend 3233705999 tiene 31 friends
# Friend --------->996662559985070080
# 143 - El friend 996662559985070080 tiene 92 friends
# Friend --------->91145174
# 144 - El friend 91145174 tiene 158 friends
# Friend --------->20897524
# Rate limit reached. Sleeping for: 887
# 145 - El friend 20897524 tiene 594 friends
# Friend --------->3088796211
# 146 - El friend 3088796211 tiene 1872 friends
# Friend --------->106012183
# 147 - El friend 106012183 tiene 1131 friends
# Friend --------->400730641
# 148 - El friend 400730641 tiene 99 friends
# Friend --------->1103400885475004416
# 149 - El friend 1103400885475004416 tiene 127 friends
# Friend --------->1163561933095821322
# 150 - El friend 1163561933095821322 tiene 360 friends
# Friend --------->722621395
# 151 - El friend 722621395 tiene 609 friends
# Friend --------->1186937974434553856
# 152 - El friend 1186937974434553856 tiene 185 friends
# Friend --------->192522831
# 153 - El friend 192522831 tiene 808 friends
# Friend --------->15255621
# 154 - El friend 15255621 tiene 2062 friends
# Friend --------->1122988172969951233
# 155 - El friend 1122988172969951233 tiene 475 friends
# Friend --------->306785937
# 156 - El friend 306785937 tiene 474 friends
# Friend --------->1457181174
# 157 - El friend 1457181174 tiene 1747 friends
# Friend --------->98369325
# 158 - El friend 98369325 tiene 26 friends
# Friend --------->3375591226
# 159 - El friend 3375591226 tiene 806 friends
# Friend --------->377228272
# Rate limit reached. Sleeping for: 887
# 160 - El friend 377228272 tiene 368 friends
# Friend --------->2180145271
# 161 - El friend 2180145271 tiene 112 friends
# Friend --------->573003960
# 162 - El friend 573003960 tiene 1 friends
# Friend --------->743044745136644096
# 163 - El friend 743044745136644096 tiene 1935 friends
# Friend --------->1189514475977805826
# 164 - El friend 1189514475977805826 tiene 22 friends
# Friend --------->1650654936
# 165 - El friend 1650654936 tiene 405 friends
# Friend --------->2802260702
# 166 - El friend 2802260702 tiene 247 friends
# Friend --------->8123772
# 167 - El friend 8123772 tiene 2149 friends
# Friend --------->1527344226
# 168 - El friend 1527344226 tiene 81 friends
# Friend --------->43808848
# 169 - El friend 43808848 tiene 21 friends
# Friend --------->741189312784551936
# 170 - El friend 741189312784551936 tiene 87 friends
# Friend --------->2907682397
# 171 - El friend 2907682397 tiene 19 friends
# Friend --------->457033547
# 172 - El friend 457033547 tiene 2326 friends
# Friend --------->1155897630830055431
# 173 - El friend 1155897630830055431 tiene 192 friends
# Friend --------->4806447291
# 174 - El friend 4806447291 tiene 1156 friends
# Friend --------->15808647
# Rate limit reached. Sleeping for: 886
# 175 - El friend 15808647 tiene 3376 friends
# Friend --------->707846480086827009
# 176 - El friend 707846480086827009 tiene 73 friends
# Friend --------->2493925164
# 177 - El friend 2493925164 tiene 428 friends
# Friend --------->279009807
# 178 - El friend 279009807 tiene 240 friends
# Friend --------->171247321
# 179 - El friend 171247321 tiene 303 friends
# Friend --------->1083448355349397504
# 180 - El friend 1083448355349397504 tiene 3574 friends
# Friend --------->193489251
# 181 - El friend 193489251 tiene 1504 friends
# Friend --------->66780587
# 182 - El friend 66780587 tiene 859 friends
# Friend --------->61718360
# 183 - El friend 61718360 tiene 320 friends
# Friend --------->1176821204
# 184 - El friend 1176821204 tiene 509 friends
# Friend --------->847527486552276992
# 185 - El friend 847527486552276992 tiene 829 friends
# Friend --------->747859187980509185
# 186 - El friend 747859187980509185 tiene 64 friends
# Friend --------->855688305740066817
# 187 - El friend 855688305740066817 tiene 898 friends
# Friend --------->746088024497217536
# 188 - El friend 746088024497217536 tiene 856 friends
# Friend --------->970004473
# 189 - El friend 970004473 tiene 783 friends
# Friend --------->854850344
# Rate limit reached. Sleeping for: 887
# 190 - El friend 854850344 tiene 323 friends
# Friend --------->784488566
# 191 - El friend 784488566 tiene 586 friends
# Friend --------->18806177
# 192 - El friend 18806177 tiene 141 friends
# Friend --------->886974667348692993
# 193 - El friend 886974667348692993 tiene 1439 friends
# Friend --------->1159748330
# 194 - El friend 1159748330 tiene 6271 friends
# Friend --------->1416961663
# 195 - El friend 1416961663 tiene 176 friends
# Friend --------->54773012
# 196 - El friend 54773012 tiene 587 friends
# Friend --------->716519803415035904
# 197 - El friend 716519803415035904 tiene 906 friends
# Friend --------->6121102
# 198 - El friend 6121102 tiene 5133 friends
# Friend --------->189564744
# 199 - El friend 189564744 tiene 396 friends
# Friend --------->749461133111791616
# 200 - El friend 749461133111791616 tiene 459 friends
# Friend --------->3988598853
# 201 - El friend 3988598853 tiene 831 friends
# Friend --------->969808506965626880
# 202 - El friend 969808506965626880 tiene 1571 friends
# Friend --------->101450586
# Rate limit reached. Sleeping for: 886
# 203 - El friend 101450586 tiene 1071 friends
# Friend --------->27615342
# 204 - El friend 27615342 tiene 305 friends
# Friend --------->14962567
# 205 - El friend 14962567 tiene 178 friends
# Friend --------->3001168696
# 206 - El friend 3001168696 tiene 154 friends
# Friend --------->1114162914519334913
# 207 - El friend 1114162914519334913 tiene 450 friends
# Friend --------->3954408094
# 208 - El friend 3954408094 tiene 130 friends
# Friend --------->382131286
# 209 - El friend 382131286 tiene 426 friends
# Friend --------->269995742
# 210 - El friend 269995742 tiene 493 friends
# Friend --------->292217941
# 211 - El friend 292217941 tiene 226 friends
# Friend --------->410633493
# 212 - El friend 410633493 tiene 458 friends
# Friend --------->159142764
# 213 - El friend 159142764 tiene 275 friends
# Friend --------->152188854
# 214 - El friend 152188854 tiene 145 friends
# Friend --------->19819652
# 215 - El friend 19819652 tiene 303 friends
# Friend --------->1173624533636583424
# 216 - El friend 1173624533636583424 tiene 768 friends
# Friend --------->26011614
# 217 - El friend 26011614 tiene 1316 friends
# Friend --------->3309533295
# Rate limit reached. Sleeping for: 888
# 218 - El friend 3309533295 tiene 141 friends
# Friend --------->295100886
# 219 - El friend 295100886 tiene 256 friends
# Friend --------->986347244713664512
# 220 - El friend 986347244713664512 tiene 110 friends
# Friend --------->302637728
# 221 - El friend 302637728 tiene 229 friends
# Friend --------->2417269134
# 222 - El friend 2417269134 tiene 1018 friends
# Friend --------->22947082
# 223 - El friend 22947082 tiene 2315 friends
# Friend --------->15376548
# 224 - El friend 15376548 tiene 547 friends
# Friend --------->614545313
# 225 - El friend 614545313 tiene 388 friends
# Friend --------->917711055937331205
# 226 - El friend 917711055937331205 tiene 285 friends
# Friend --------->274592041
# 227 - El friend 274592041 tiene 2675 friends
# Friend --------->972467273012260864
# 228 - El friend 972467273012260864 tiene 499 friends
# Friend --------->245853481
# 229 - El friend 245853481 tiene 1140 friends
# Friend --------->376094852
# 230 - El friend 376094852 tiene 448 friends
# Friend --------->16831576
# 231 - El friend 16831576 tiene 1810 friends
# Friend --------->1905448747
# 232 - El friend 1905448747 tiene 218 friends
# Friend --------->2432546442
# Rate limit reached. Sleeping for: 886
# 233 - El friend 2432546442 tiene 461 friends
# Friend --------->22128199
# 234 - El friend 22128199 tiene 2542 friends
# Friend --------->7097342
# 235 - El friend 7097342 tiene 1077 friends
# Friend --------->43210905
# 236 - El friend 43210905 tiene 2433 friends
# Friend --------->46371624
# 237 - El friend 46371624 tiene 3411 friends
# Friend --------->472745446
# 238 - El friend 472745446 tiene 488 friends
# Friend --------->238544535
# 239 - El friend 238544535 tiene 191 friends
# Friend --------->58468032
# 240 - El friend 58468032 tiene 318 friends
# Friend --------->127540856
# 241 - El friend 127540856 tiene 404 friends
# Friend --------->188300159
# 242 - El friend 188300159 tiene 2138 friends
# Friend --------->60598243
# 243 - El friend 60598243 tiene 77 friends
# Friend --------->193858718
# 244 - El friend 193858718 tiene 3418 friends
# Friend --------->635509679
# 245 - El friend 635509679 tiene 399 friends
# Friend --------->232143669
# 246 - El friend 232143669 tiene 429 friends
# Friend --------->390726825
# 247 - El friend 390726825 tiene 281 friends
# Friend --------->109077710
# Rate limit reached. Sleeping for: 887
# 248 - El friend 109077710 tiene 328 friends
# Friend --------->165101386
# 249 - El friend 165101386 tiene 1360 friends
# Friend --------->166248568
# 250 - El friend 166248568 tiene 253 friends
# Friend --------->480675282
# 251 - El friend 480675282 tiene 78 friends
# Friend --------->458503851
# 252 - El friend 458503851 tiene 133 friends
# Friend --------->358454569
# 253 - El friend 358454569 tiene 101 friends
# Friend --------->417478542
# 254 - El friend 417478542 tiene 275 friends
# Friend --------->272628940
# 255 - El friend 272628940 tiene 424 friends
# Friend --------->69091975
# 256 - El friend 69091975 tiene 643 friends
# Friend --------->467318693
# 257 - El friend 467318693 tiene 41 friends
# Friend --------->104154171
# 258 - El friend 104154171 tiene 342 friends
# Friend --------->49126592
# 259 - El friend 49126592 tiene 418 friends
# Friend --------->75495576
# 260 - El friend 75495576 tiene 264 friends
# Friend --------->148280014
# 261 - El friend 148280014 tiene 9828 friends
# Friend --------->7851782
# Rate limit reached. Sleeping for: 887
# 262 - El friend 7851782 tiene 2805 friends
# Friend --------->34371202
# 263 - El friend 34371202 tiene 1582 friends
# Friend --------->363884751
# 264 - El friend 363884751 tiene 822 friends
# Friend --------->144801834
# 265 - El friend 144801834 tiene 1135 friends
# Friend --------->17989872
# 266 - El friend 17989872 tiene 1352 friends
# Friend --------->213474460
# 267 - El friend 213474460 tiene 401 friends
# Friend --------->47359208
# 268 - El friend 47359208 tiene 1963 friends
# Friend --------->61419664
# 269 - El friend 61419664 tiene 143 friends
# Friend --------->839144408
# 270 - El friend 839144408 tiene 1394 friends
# Friend --------->244944088
# 271 - El friend 244944088 tiene 3889 friends
# Friend --------->255008507
# 272 - El friend 255008507 tiene 832 friends
# Friend --------->338255079
# 273 - El friend 338255079 tiene 19700 friends
# Friend --------->931710002
# Rate limit reached. Sleeping for: 885
# 274 - El friend 931710002 tiene 94 friends
# Friend --------->2428806922
# 275 - El friend 2428806922 tiene 7204 friends
# Friend --------->3619575269
# 276 - El friend 3619575269 tiene 421 friends
# Friend --------->2857378955
# 277 - El friend 2857378955 tiene 250 friends
# Friend --------->275544348
# 278 - El friend 275544348 tiene 162 friends
# Friend --------->535308648
# 279 - El friend 535308648 tiene 274 friends
# Friend --------->324857822
# 280 - El friend 324857822 tiene 3186 friends
# Friend --------->257460272
# 281 - El friend 257460272 tiene 1010 friends
# Friend --------->1940138088
# 282 - El friend 1940138088 tiene 29 friends
# Friend --------->249040542
# 283 - El friend 249040542 tiene 350 friends
# Friend --------->386194945
# 284 - El friend 386194945 tiene 124 friends
# Friend --------->177878056
# 285 - El friend 177878056 tiene 13902 friends
# Friend --------->230418390
# Rate limit reached. Sleeping for: 886
# 286 - El friend 230418390 tiene 743 friends
# Friend --------->789595098174685184
# 287 - El friend 789595098174685184 tiene 739 friends
# Friend --------->913124629430104065
# 288 - El friend 913124629430104065 tiene 203 friends
# Friend --------->721143251940601857
# 289 - El friend 721143251940601857 tiene 1077 friends
# Friend --------->3109805067
# 290 - El friend 3109805067 tiene 618 friends
# Friend --------->35705071
# 291 - El friend 35705071 tiene 4943 friends
# Friend --------->870352320999165952
# 292 - El friend 870352320999165952 tiene 761 friends
# Friend --------->1075910966
# Rate limit reached. Sleeping for: 883
# Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Read timed out. (read timeout=60)
# Friend --------->2099361
# 294 - El friend 2099361 tiene 1460 friends
# Friend --------->38458095
# 295 - El friend 38458095 tiene 20288 friends
# Friend --------->1379795863
# 296 - El friend 1379795863 tiene 5001 friends
# Friend --------->1330166688
# 297 - El friend 1330166688 tiene 1960 friends
# Friend --------->369247037
# 298 - El friend 369247037 tiene 2858 friends
# Friend --------->96730899
# 299 - El friend 96730899 tiene 4339 friends
# Friend --------->264186880
# 300 - El friend 264186880 tiene 670 friends
# Friend --------->267197904
# 301 - El friend 267197904 tiene 4292 friends
# Friend --------->959103221687087104
# 302 - El friend 959103221687087104 tiene 777 friends
# Friend --------->2520691851
# 303 - El friend 2520691851 tiene 4113 friends
# Friend --------->266230149
# Rate limit reached. Sleeping for: 883
# 304 - El friend 266230149 tiene 1072 friends
# Friend --------->52785084
# 305 - El friend 52785084 tiene 1850 friends
# Friend --------->636288299
# 306 - El friend 636288299 tiene 148 friends
# Friend --------->1069014080
# 307 - El friend 1069014080 tiene 700 friends
# Friend --------->776122061072715776
# 308 - El friend 776122061072715776 tiene 321 friends
# Friend --------->385462306
# 309 - El friend 385462306 tiene 2633 friends
# Friend --------->235346355
# 310 - El friend 235346355 tiene 546 friends
# Friend --------->1365482233
# 311 - El friend 1365482233 tiene 3818 friends
# Friend --------->1353554534
# 312 - El friend 1353554534 tiene 354 friends
# Friend --------->392599021
# 313 - El friend 392599021 tiene 595 friends
# Friend --------->1922819430
# 314 - El friend 1922819430 tiene 3695 friends
# Friend --------->126602043
# 315 - El friend 126602043 tiene 1124 friends
# Friend --------->221175879
# 316 - El friend 221175879 tiene 1307 friends
# Friend --------->536435650
# 317 - El friend 536435650 tiene 388 friends
# Friend --------->488306225
# 318 - El friend 488306225 tiene 3887 friends
# Friend --------->12339482
# Rate limit reached. Sleeping for: 886
# 319 - El friend 12339482 tiene 1243 friends
# Friend --------->18728192
# 320 - El friend 18728192 tiene 359 friends
# Friend --------->267078766
# 321 - El friend 267078766 tiene 1166 friends
# Friend --------->230501444
# 322 - El friend 230501444 tiene 135 friends
# Friend --------->55869617
# 323 - El friend 55869617 tiene 250 friends
# Friend --------->4807939768
# 324 - El friend 4807939768 tiene 336 friends
# Friend --------->1951680043
# 325 - El friend 1951680043 tiene 376 friends
# Friend --------->1345030855
# 326 - El friend 1345030855 tiene 703 friends
# Friend --------->2491554596
# 327 - El friend 2491554596 tiene 344 friends
# Friend --------->14508371
# 328 - El friend 14508371 tiene 345 friends
# Friend --------->263560502
# 329 - El friend 263560502 tiene 3942 friends
# Friend --------->2184042338
# 330 - El friend 2184042338 tiene 537 friends
# Friend --------->2509973791
# 331 - El friend 2509973791 tiene 999 friends
# Friend --------->18684324
# 332 - El friend 18684324 tiene 2133 friends
# Friend --------->605442165
# 333 - El friend 605442165 tiene 485 friends
# Friend --------->965711714108035073
# Rate limit reached. Sleeping for: 887
# Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Read timed out. (read timeout=60)
# Friend --------->228061245
# Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/friends/ids.json?id=228061245&cursor=-1 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fefe9302cd0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Friend --------->536567540
# Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/friends/ids.json?id=536567540&cursor=-1 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fefe5d59dd0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Friend --------->2924764113
# Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/friends/ids.json?id=2924764113&cursor=-1 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fefe5d59990>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Friend --------->966242184981860357
# Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/friends/ids.json?id=966242184981860357&cursor=-1 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fefe5b2f150>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Friend --------->2837207494
# Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/friends/ids.json?id=2837207494&cursor=-1 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7feff7da97d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Friend --------->748930737307525120
# Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/friends/ids.json?id=748930737307525120&cursor=-1 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fefe9302a10>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Friend --------->1172470300979671040
# Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/friends/ids.json?id=1172470300979671040&cursor=-1 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7feff7f887d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Friend --------->75079616
# 342 - El friend 75079616 tiene 344 friends
# Friend --------->137647056
# 343 - El friend 137647056 tiene 1116 friends
# Friend --------->4363421476
# 344 - El friend 4363421476 tiene 3714 friends
# Friend --------->91985735
# 345 - El friend 91985735 tiene 661 friends
# Friend --------->13334762
# 346 - El friend 13334762 tiene 312 friends
# Friend --------->18060279
# 347 - El friend 18060279 tiene 6541 friends
# Friend --------->203992327
# 348 - El friend 203992327 tiene 9 friends
# Friend --------->44759260
# 349 - El friend 44759260 tiene 231 friends
# Friend --------->762071527328210944
# 350 - El friend 762071527328210944 tiene 805 friends
# Friend --------->2856920883
# 351 - El friend 2856920883 tiene 1495 friends
# Friend --------->760515512577224704
# 352 - El friend 760515512577224704 tiene 554 friends
# Friend --------->715476691460558848
# 353 - El friend 715476691460558848 tiene 700 friends
# Friend --------->4832112171
# 354 - El friend 4832112171 tiene 2904 friends
# Friend --------->1251420991
# Rate limit reached. Sleeping for: 138
# 355 - El friend 1251420991 tiene 5 friends
# Friend --------->911946638289199104
# 356 - El friend 911946638289199104 tiene 3835 friends
# Friend --------->2848528606
# 357 - El friend 2848528606 tiene 51 friends
# Friend --------->786588345585500160
# 358 - El friend 786588345585500160 tiene 3615 friends
# Friend --------->3363872993
# 359 - El friend 3363872993 tiene 3556 friends
# Friend --------->288332356
# 360 - El friend 288332356 tiene 222 friends
# Friend --------->86998264
# 361 - El friend 86998264 tiene 4848 friends
# Friend --------->17925320
# 362 - El friend 17925320 tiene 168 friends
# Friend --------->756348385368485888
# 363 - El friend 756348385368485888 tiene 255 friends
# Friend --------->2743718988
# 364 - El friend 2743718988 tiene 177 friends
# Friend --------->133415881
# 365 - El friend 133415881 tiene 1069 friends
# Friend --------->231495872
# 366 - El friend 231495872 tiene 160 friends
# Friend --------->145669983
# 367 - El friend 145669983 tiene 143 friends
# Friend --------->14092803
# 368 - El friend 14092803 tiene 1861 friends
# Friend --------->1146799924455137281
# 369 - El friend 1146799924455137281 tiene 1740 friends
# Friend --------->785618379201654784
# Rate limit reached. Sleeping for: 885
# 370 - El friend 785618379201654784 tiene 3 friends
# Friend --------->717936015470493697
# 371 - El friend 717936015470493697 tiene 55 friends
# Friend --------->1136271623559012353
# 372 - El friend 1136271623559012353 tiene 67 friends
# Friend --------->733683745547522048
# 373 - El friend 733683745547522048 tiene 232 friends
# Friend --------->1322643361
# 374 - El friend 1322643361 tiene 298 friends
# Friend --------->977147376703025152
# 375 - El friend 977147376703025152 tiene 50 friends
# Friend --------->1706503148
# 376 - El friend 1706503148 tiene 154 friends
# Friend --------->880146071049175040
# 377 - El friend 880146071049175040 tiene 283 friends
# Friend --------->974784707098529792
# 378 - El friend 974784707098529792 tiene 1038 friends
# Friend --------->374479950
# 379 - El friend 374479950 tiene 145 friends
# Friend --------->1038134338305581057
# 380 - El friend 1038134338305581057 tiene 84 friends
# Friend --------->912745614823317504
# 381 - El friend 912745614823317504 tiene 111 friends
# Friend --------->3226938653
# 382 - El friend 3226938653 tiene 598 friends
# Friend --------->1134731744350019584
# 383 - El friend 1134731744350019584 tiene 65 friends
# Friend --------->338259207
# 384 - El friend 338259207 tiene 626 friends
# Friend --------->292394973
# Rate limit reached. Sleeping for: 887
# Failed to send request: ('Connection aborted.', OSError("(60, 'ETIMEDOUT')"))
# Friend --------->1063369418758074368
# Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/friends/ids.json?id=1063369418758074368&cursor=-1 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fefe6fd9890>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Friend --------->1098874382980730880
# Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/friends/ids.json?id=1098874382980730880&cursor=-1 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7feff7d709d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Friend --------->702932794947694592
# 388 - El friend 702932794947694592 tiene 480 friends
# Friend --------->15068820
# 389 - El friend 15068820 tiene 917 friends
# Friend --------->5202811
# 390 - El friend 5202811 tiene 651 friends
# Friend --------->1108444650745024512
# 391 - El friend 1108444650745024512 tiene 651 friends
# Friend --------->1062483629886988288
# 392 - El friend 1062483629886988288 tiene 4394 friends
# Friend --------->254107028
# 393 - El friend 254107028 tiene 99 friends
# Friend --------->776585502606721024
# 394 - El friend 776585502606721024 tiene 29 friends
# Friend --------->385343072
# 395 - El friend 385343072 tiene 822 friends
# Friend --------->1098880408668774400
# 396 - El friend 1098880408668774400 tiene 27 friends
# Friend --------->276898155
# 397 - El friend 276898155 tiene 83 friends
# Friend --------->15936194
# 398 - El friend 15936194 tiene 9499 friends
# Friend --------->887092910277013504
# 399 - El friend 887092910277013504 tiene 463 friends
# Friend --------->930204502807920641
# 400 - El friend 930204502807920641 tiene 3 friends
# Friend --------->2919063234
# 401 - El friend 2919063234 tiene 13 friends
# Friend --------->1105031494282690561
# Rate limit reached. Sleeping for: 887
# 402 - El friend 1105031494282690561 tiene 138 friends
# Friend --------->799575607420026882
# 403 - El friend 799575607420026882 tiene 210 friends
# Friend --------->2501050340
# 404 - El friend 2501050340 tiene 322 friends
# Friend --------->415612502
# 405 - El friend 415612502 tiene 282 friends
# Friend --------->1084777902380584960
# 406 - El friend 1084777902380584960 tiene 61 friends
# Friend --------->1058374118377164800
# 407 - El friend 1058374118377164800 tiene 164 friends
# Friend --------->1083494965
# 408 - El friend 1083494965 tiene 333 friends
# Friend --------->805600
# 409 - El friend 805600 tiene 3008 friends
# Friend --------->1082751622797819906
# 410 - El friend 1082751622797819906 tiene 45 friends
# Friend --------->120596672
# 411 - El friend 120596672 tiene 1120 friends
# Friend --------->196539787
# 412 - El friend 196539787 tiene 445 friends
# Friend --------->833077330360807425
# 413 - El friend 833077330360807425 tiene 3627 friends
# Friend --------->572146643
# 414 - El friend 572146643 tiene 416 friends
# Friend --------->1065046646373920770
# 415 - El friend 1065046646373920770 tiene 589 friends
# Friend --------->16808969
# 416 - El friend 16808969 tiene 849 friends
# Friend --------->761589870
# Rate limit reached. Sleeping for: 887
# 417 - El friend 761589870 tiene 73 friends
# Friend --------->14208559
# 418 - El friend 14208559 tiene 211 friends
# Friend --------->998282257097019392
# 419 - El friend 998282257097019392 tiene 648 friends
# Friend --------->1390398596
# 420 - El friend 1390398596 tiene 20 friends
# Friend --------->1071835874525134848
# 421 - El friend 1071835874525134848 tiene 140 friends
# Friend --------->763102211639537665
# 422 - El friend 763102211639537665 tiene 781 friends
# Friend --------->875124704
# 423 - El friend 875124704 tiene 8 friends
# Friend --------->1062685860087414784
# 424 - El friend 1062685860087414784 tiene 189 friends
# Friend --------->1084771371329175552
# 425 - El friend 1084771371329175552 tiene 158 friends
# Friend --------->534857422
# 426 - El friend 534857422 tiene 5211 friends
# Friend --------->940911512599912448
# 427 - El friend 940911512599912448 tiene 349 friends
# Friend --------->532549195
# 428 - El friend 532549195 tiene 238 friends
# Friend --------->783033302911426560
# 429 - El friend 783033302911426560 tiene 557 friends
# Friend --------->3312733700
# 430 - El friend 3312733700 tiene 234 friends
# Friend --------->408847389
# Rate limit reached. Sleeping for: 887
# 431 - El friend 408847389 tiene 187 friends
# Friend --------->3014515420
# 432 - El friend 3014515420 tiene 467 friends
# Friend --------->33851918
# 433 - El friend 33851918 tiene 380 friends
# Friend --------->1513816064
# 434 - El friend 1513816064 tiene 505 friends
# Friend --------->8144482
# 435 - El friend 8144482 tiene 509 friends
# Friend --------->971174452414173184
# 436 - El friend 971174452414173184 tiene 9 friends
# Friend --------->3762060929
# 437 - El friend 3762060929 tiene 1218 friends
# Friend --------->247290350
# 438 - El friend 247290350 tiene 391 friends
# Friend --------->4444302499
# 439 - El friend 4444302499 tiene 550 friends
# Friend --------->899972426938937344
# 440 - El friend 899972426938937344 tiene 700 friends
# Friend --------->350411337
# 441 - El friend 350411337 tiene 185 friends
# Friend --------->980846595737640965
# 442 - El friend 980846595737640965 tiene 455 friends
# Friend --------->2409345738
# 443 - El friend 2409345738 tiene 417 friends
# Friend --------->294566196
# 444 - El friend 294566196 tiene 950 friends
# Friend --------->804683095869976580
# 445 - El friend 804683095869976580 tiene 127 friends
# Friend --------->380284391
# Rate limit reached. Sleeping for: 887
# 446 - El friend 380284391 tiene 2874 friends
# Friend --------->223510658
# 447 - El friend 223510658 tiene 678 friends
# Friend --------->1033648956499222528
# 448 - El friend 1033648956499222528 tiene 1348 friends
# Friend --------->387665591
# 449 - El friend 387665591 tiene 392 friends
# Friend --------->61063145
# 450 - El friend 61063145 tiene 158 friends
# Friend --------->1009698539562328064
# 451 - El friend 1009698539562328064 tiene 30 friends
# Friend --------->995638438836744192
# 452 - El friend 995638438836744192 tiene 53 friends
# Friend --------->543290433
# 453 - El friend 543290433 tiene 88 friends
# Friend --------->973918686
# 454 - El friend 973918686 tiene 17 friends
# Friend --------->877549088
# 455 - El friend 877549088 tiene 1172 friends
# Friend --------->799735368849367040
# 456 - El friend 799735368849367040 tiene 199 friends
# Friend --------->1625516300
# 457 - El friend 1625516300 tiene 168 friends
# Friend --------->825749703857938434
# 458 - El friend 825749703857938434 tiene 89 friends
# Friend --------->804071774182903808
# 459 - El friend 804071774182903808 tiene 895 friends
# Friend --------->761153947990097920
# 460 - El friend 761153947990097920 tiene 1263 friends
# Friend --------->817226966
# Rate limit reached. Sleeping for: 887
# Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Read timed out. (read timeout=60)
# Friend --------->479515259
# 462 - El friend 479515259 tiene 602 friends
# Friend --------->2955195436
# 463 - El friend 2955195436 tiene 772 friends
# Friend --------->1064107576349130752
# 464 - El friend 1064107576349130752 tiene 462 friends
# Friend --------->778953169183338496
# 465 - El friend 778953169183338496 tiene 231 friends
# Friend --------->822083844065165312
# 466 - El friend 822083844065165312 tiene 76 friends
# Friend --------->971796017543897088
# 467 - El friend 971796017543897088 tiene 470 friends
# Friend --------->2845131426
# 468 - El friend 2845131426 tiene 109 friends
# Friend --------->1050049831027257346
# 469 - El friend 1050049831027257346 tiene 35 friends
# Friend --------->361338458
# 470 - El friend 361338458 tiene 271 friends
# Friend --------->236948620
# 471 - El friend 236948620 tiene 608 friends
# Friend --------->776070390980411393
# 472 - El friend 776070390980411393 tiene 184 friends
# Friend --------->380504023
# 473 - El friend 380504023 tiene 367 friends
# Friend --------->852532959953510400
# 474 - El friend 852532959953510400 tiene 254 friends
# Friend --------->888170281768034305
# 475 - El friend 888170281768034305 tiene 1 friends
# Friend --------->888201341583196160
# 476 - El friend 888201341583196160 tiene 194 friends
# Friend --------->781157743008907264
# Rate limit reached. Sleeping for: 888
# 477 - El friend 781157743008907264 tiene 4 friends
# Friend --------->4874460712
# 478 - El friend 4874460712 tiene 686 friends
# Friend --------->1029317694674415616
# 479 - El friend 1029317694674415616 tiene 535 friends
# Friend --------->3063892619
# 480 - El friend 3063892619 tiene 303 friends
# Friend --------->57266771
# 481 - El friend 57266771 tiene 5534 friends
# Friend --------->14306573
# 482 - El friend 14306573 tiene 338 friends
# Friend --------->9524342
# 483 - El friend 9524342 tiene 970 friends
# Friend --------->803912469928443904
# 484 - El friend 803912469928443904 tiene 11 friends
# Friend --------->1541554483
# 485 - El friend 1541554483 tiene 11 friends
# Friend --------->876784384703115264
# 486 - El friend 876784384703115264 tiene 215 friends
# Friend --------->4764861076
# 487 - El friend 4764861076 tiene 0 friends
# Friend --------->86074234
# 488 - El friend 86074234 tiene 409 friends
# Friend --------->997027316093014016
# 489 - El friend 997027316093014016 tiene 65 friends
# Friend --------->1726747806
# 490 - El friend 1726747806 tiene 2 friends
# Friend --------->4254567554
# Rate limit reached. Sleeping for: 888
# 491 - El friend 4254567554 tiene 2213 friends
# Friend --------->3308677377
# 492 - El friend 3308677377 tiene 0 friends
# Friend --------->2654164081
# 493 - El friend 2654164081 tiene 370 friends
# Friend --------->944237461697331200
# 494 - El friend 944237461697331200 tiene 0 friends
# Friend --------->1100636048
# 495 - El friend 1100636048 tiene 491 friends
# Friend --------->876624356
# 496 - El friend 876624356 tiene 215 friends
# Friend --------->23257215
# 497 - El friend 23257215 tiene 1689 friends
# Friend --------->719774079
# 498 - El friend 719774079 tiene 898 friends
# Friend --------->935790926047432704
# 499 - El friend 935790926047432704 tiene 27 friends
# Friend --------->796657147639631872
# 500 - El friend 796657147639631872 tiene 434 friends
# Friend --------->94926712
# 501 - El friend 94926712 tiene 189 friends
# Friend --------->952129529782337536
# 502 - El friend 952129529782337536 tiene 1 friends
# Friend --------->586043084
# 503 - El friend 586043084 tiene 1682 friends
# Friend --------->16088415
# 504 - El friend 16088415 tiene 1034 friends
# Friend --------->82388403
# 505 - El friend 82388403 tiene 744 friends
# Friend --------->186805162
# Rate limit reached. Sleeping for: 888
# 506 - El friend 186805162 tiene 333 friends
# Friend --------->82172798
# 507 - El friend 82172798 tiene 2756 friends
# Friend --------->827646604509315072
# 508 - El friend 827646604509315072 tiene 966 friends
# Friend --------->407310786
# 509 - El friend 407310786 tiene 824 friends
# Friend --------->1003834339
# 510 - El friend 1003834339 tiene 40 friends
# Friend --------->85278192
# 511 - El friend 85278192 tiene 597 friends
# Friend --------->59133365
# 512 - El friend 59133365 tiene 602 friends
# Friend --------->974473542
# 513 - El friend 974473542 tiene 670 friends
# Friend --------->972213248643751936
# 514 - El friend 972213248643751936 tiene 49 friends
# Friend --------->28767737
# 515 - El friend 28767737 tiene 2068 friends
# Friend --------->705086409175142400
# 516 - El friend 705086409175142400 tiene 130 friends
# Friend --------->824179484190507008
# 517 - El friend 824179484190507008 tiene 0 friends
# Friend --------->881986786502860801
# 518 - El friend 881986786502860801 tiene 144 friends
# Friend --------->1956067290
# 519 - El friend 1956067290 tiene 37 friends
# Friend --------->254542744
# 520 - El friend 254542744 tiene 386 friends
# Friend --------->135297570
# Rate limit reached. Sleeping for: 887
# 521 - El friend 135297570 tiene 91 friends
# Friend --------->153025507
# 522 - El friend 153025507 tiene 544 friends
# Friend --------->107182792
# 523 - El friend 107182792 tiene 923 friends
# Friend --------->90323375
# 524 - El friend 90323375 tiene 769 friends
# Friend --------->971875313046220801
# 525 - El friend 971875313046220801 tiene 33 friends
# Friend --------->798588918497247232
# 526 - El friend 798588918497247232 tiene 356 friends
# Friend --------->414972658
# 527 - El friend 414972658 tiene 217 friends
# Friend --------->3010529230
# 528 - El friend 3010529230 tiene 609 friends
# Friend --------->978963906327662594
# 529 - El friend 978963906327662594 tiene 31 friends
# Friend --------->719147860852416512
# 530 - El friend 719147860852416512 tiene 280 friends
# Friend --------->1138959692
# 531 - El friend 1138959692 tiene 3401 friends
# Friend --------->246026948
# 532 - El friend 246026948 tiene 691 friends
# Friend --------->789073212
# 533 - El friend 789073212 tiene 617 friends
# Friend --------->822915157366099968
# 534 - El friend 822915157366099968 tiene 104 friends
# Friend --------->923827448613089280
# 535 - El friend 923827448613089280 tiene 39 friends
# Friend --------->323737040
# ...
# Friend --------->538022188
# 539 - El friend 538022188 tiene 205 friends
# Friend --------->212714890
# 540 - El friend 212714890 tiene 737 friends
# Friend --------->784788842733862912
# 541 - El friend 784788842733862912 tiene 512 friends
# Friend --------->81709031
# 542 - El friend 81709031 tiene 24 friends
# Friend --------->3537196463
# 543 - El friend 3537196463 tiene 6 friends
# Friend --------->1260162271
# 544 - El friend 1260162271 tiene 256 friends
# Friend --------->202346566
# 545 - El friend 202346566 tiene 162 friends
# Friend --------->207711504
# 546 - El friend 207711504 tiene 157 friends
# Friend --------->872801480906035200
# 547 - El friend 872801480906035200 tiene 141 friends
# Friend --------->3028533922
# Rate limit reached. Sleeping for: 885
# 548 - El friend 3028533922 tiene 753 friends
# Friend --------->916181846131699712
# 549 - El friend 916181846131699712 tiene 409 friends
# Friend --------->269989805
# 550 - El friend 269989805 tiene 782 friends
# Friend --------->283973320
# 551 - El friend 283973320 tiene 515 friends
# Friend --------->152022069
# 552 - El friend 152022069 tiene 3229 friends
# Friend --------->1269712388
# 553 - El friend 1269712388 tiene 12 friends
# Friend --------->3364396215
# 554 - El friend 3364396215 tiene 1039 friends
# Friend --------->766181090
# 555 - El friend 766181090 tiene 158 friends
# Friend --------->915976368571027457
# 556 - El friend 915976368571027457 tiene 356 friends
# Friend --------->754248284844204032
# 557 - El friend 754248284844204032 tiene 527 friends
# Friend --------->901332564647919616
# 558 - El friend 901332564647919616 tiene 13 friends
# Friend --------->822368103065493505
# 559 - El friend 822368103065493505 tiene 22 friends
# Friend --------->873254887848648705
# 560 - El friend 873254887848648705 tiene 345 friends
# Friend --------->811143067881369600
# 561 - El friend 811143067881369600 tiene 524 friends
# Friend --------->906469877753565184
# 562 - El friend 906469877753565184 tiene 375 friends
# Friend --------->930376599228297217
# Rate limit reached. Sleeping for: 889
# 563 - El friend 930376599228297217 tiene 218 friends
# Friend --------->156922766
# 564 - El friend 156922766 tiene 249 friends
# Friend --------->372605954
# 565 - El friend 372605954 tiene 4 friends
# Friend --------->760903253425020928
# 566 - El friend 760903253425020928 tiene 315 friends
# Friend --------->3081302315
# 567 - El friend 3081302315 tiene 7020 friends
# Friend --------->147576853
# 568 - El friend 147576853 tiene 32 friends
# Friend --------->733454251
# 569 - El friend 733454251 tiene 124 friends
# Friend --------->3395115614
# 570 - El friend 3395115614 tiene 88 friends
# Friend --------->787973543833268224
# 571 - El friend 787973543833268224 tiene 222 friends
# Friend --------->110380312
# 572 - El friend 110380312 tiene 1641 friends
# Friend --------->3379244896
# 573 - El friend 3379244896 tiene 634 friends
# Friend --------->2821368996
# 574 - El friend 2821368996 tiene 771 friends
# Friend --------->11348282
# 575 - El friend 11348282 tiene 218 friends
# Friend --------->34743251
# 576 - El friend 34743251 tiene 90 friends
# Friend --------->44196397
# Rate limit reached. Sleeping for: 888
# 577 - El friend 44196397 tiene 91 friends
# Friend --------->2362618909
# 578 - El friend 2362618909 tiene 743 friends
# Friend --------->476149882
# 579 - El friend 476149882 tiene 1669 friends
# Friend --------->82894804
# 580 - El friend 82894804 tiene 810 friends
# Friend --------->376105506
# 581 - El friend 376105506 tiene 814 friends
# Friend --------->387765338
# 582 - El friend 387765338 tiene 180 friends
# Friend --------->2905440476
# 583 - El friend 2905440476 tiene 98 friends
# Friend --------->770637060713619456
# 584 - El friend 770637060713619456 tiene 153 friends
# Friend --------->796401411454095360
# 585 - El friend 796401411454095360 tiene 80 friends
# Friend --------->972651
# 586 - El friend 972651 tiene 2751 friends
# Friend --------->34981502
# 587 - El friend 34981502 tiene 2002 friends
# Friend --------->292250093
# 588 - El friend 292250093 tiene 1630 friends
# Friend --------->602643038
# 589 - El friend 602643038 tiene 910 friends
# Friend --------->46679614
# 590 - El friend 46679614 tiene 1209 friends
# Friend --------->188653902
# 591 - El friend 188653902 tiene 3425 friends
# Friend --------->16843780
# Rate limit reached. Sleeping for: 887
# Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Read timed out. (read timeout=60)
# Friend --------->134447383
# 593 - El friend 134447383 tiene 1650 friends
# Friend --------->7597362
# 594 - El friend 7597362 tiene 2924 friends
# Friend --------->224807095
# 595 - El friend 224807095 tiene 1451 friends
# Friend --------->2390821243
# 596 - El friend 2390821243 tiene 0 friends
# Friend --------->2227093650
# 597 - El friend 2227093650 tiene 264 friends
# Friend --------->1156808526
# 598 - El friend 1156808526 tiene 1006 friends
# Friend --------->2340826736
# 599 - El friend 2340826736 tiene 442 friends
# Friend --------->383690116
# 600 - El friend 383690116 tiene 1209 friends
# Friend --------->465901182
# 601 - El friend 465901182 tiene 2153 friends
# Friend --------->3373812033
# 602 - El friend 3373812033 tiene 1035 friends
# Friend --------->2226355735
# 603 - El friend 2226355735 tiene 120 friends
# Friend --------->362565198
# 604 - El friend 362565198 tiene 401 friends
# Friend --------->4901708113
# 605 - El friend 4901708113 tiene 484 friends
# Friend --------->31263739
# 606 - El friend 31263739 tiene 1760 friends
# Friend --------->1286558558
# 607 - El friend 1286558558 tiene 824 friends
# Friend --------->1283468348
# Rate limit reached. Sleeping for: 887
# 608 - El friend 1283468348 tiene 411 friends
# Friend --------->1085912654
# 609 - El friend 1085912654 tiene 1301 friends
# Friend --------->1907436986
# 610 - El friend 1907436986 tiene 421 friends
# Friend --------->850257742694502400
# 611 - El friend 850257742694502400 tiene 264 friends
# Friend --------->884738184
# 612 - El friend 884738184 tiene 4129 friends
# Friend --------->79698455
# 613 - El friend 79698455 tiene 181 friends
# Friend --------->811529835449372672
# 614 - El friend 811529835449372672 tiene 15 friends
# Friend --------->82445809
# 615 - El friend 82445809 tiene 5639 friends
# Friend --------->2817270167
# 616 - El friend 2817270167 tiene 779 friends
# Friend --------->110951735
# 617 - El friend 110951735 tiene 4152 friends
# Friend --------->2972907299
# 618 - El friend 2972907299 tiene 521 friends
# Friend --------->104008761
# 619 - El friend 104008761 tiene 1400 friends
# Friend --------->96122488
# 620 - El friend 96122488 tiene 846 friends
# Friend --------->2483117419
# Rate limit reached. Sleeping for: 886
# 621 - El friend 2483117419 tiene 20799 friends
# Friend --------->389520836
# 622 - El friend 389520836 tiene 207 friends
# Friend --------->2210254026
# 623 - El friend 2210254026 tiene 453 friends
# Friend --------->207020204
# 624 - El friend 207020204 tiene 1758 friends
# Friend --------->415748754
# 625 - El friend 415748754 tiene 172 friends
# Friend --------->1217805109
# 626 - El friend 1217805109 tiene 7343 friends
# Friend --------->781512273185701888
# 627 - El friend 781512273185701888 tiene 587 friends
# Friend --------->389079373
# 628 - El friend 389079373 tiene 216 friends
# Friend --------->811976703962738688
# 629 - El friend 811976703962738688 tiene 985 friends
# Friend --------->75992554
# 630 - El friend 75992554 tiene 579 friends
# Friend --------->2961088559
# 631 - El friend 2961088559 tiene 1359 friends
# Friend --------->243342953
# Rate limit reached. Sleeping for: 886
# 632 - El friend 243342953 tiene 8392 friends
# Friend --------->254957695
# 633 - El friend 254957695 tiene 1180 friends
# Friend --------->1030298773
# 634 - El friend 1030298773 tiene 3607 friends
# Friend --------->1242298909
# 635 - El friend 1242298909 tiene 6793 friends
# Friend --------->139737474
# 636 - El friend 139737474 tiene 1634 friends
# Friend --------->745205027296382976
# 637 - El friend 745205027296382976 tiene 2543 friends
# Friend --------->2876183963
# 638 - El friend 2876183963 tiene 518 friends
# Friend --------->891524280
# 639 - El friend 891524280 tiene 4088 friends
# Friend --------->540757324
# 640 - El friend 540757324 tiene 2904 friends
# Friend --------->3360888502
# 641 - El friend 3360888502 tiene 957 friends
# Friend --------->16163403
# 642 - El friend 16163403 tiene 3559 friends
# Friend --------->283009950
# 643 - El friend 283009950 tiene 640 friends
# Friend --------->4438320034
# 644 - El friend 4438320034 tiene 1447 friends
# Friend --------->2889353031
# Rate limit reached. Sleeping for: 884
# Failed to send request: ('Connection aborted.', OSError("(60, 'ETIMEDOUT')"))
# Friend --------->760785007522840577
# 646 - El friend 760785007522840577 tiene 689 friends
# Friend --------->1851048374
# 647 - El friend 1851048374 tiene 1517 friends
# Friend --------->739171924811649024
# 648 - El friend 739171924811649024 tiene 43 friends
# Friend --------->1474021
# 649 - El friend 1474021 tiene 1041 friends
# Friend --------->3129465869
# 650 - El friend 3129465869 tiene 3 friends
# Friend --------->903378957101355010
# 651 - El friend 903378957101355010 tiene 63 friends
# Friend --------->183070035
# 652 - El friend 183070035 tiene 899 friends
# Friend --------->18939115
# Rate limit reached. Sleeping for: 885
# 653 - El friend 18939115 tiene 82573 friends
# Friend --------->312557956
# 654 - El friend 312557956 tiene 270 friends
# Friend --------->2173470477
# 655 - El friend 2173470477 tiene 168 friends
# Friend --------->45249233
# 656 - El friend 45249233 tiene 12572 friends
# Friend --------->2674921
# 657 - El friend 2674921 tiene 1756 friends
# Friend --------->374764289
# Rate limit reached. Sleeping for: 883
# 658 - El friend 374764289 tiene 1178 friends
# Friend --------->193262712
# 659 - El friend 193262712 tiene 520 friends
# Friend --------->2940228218
# 660 - El friend 2940228218 tiene 306 friends
# Friend --------->491341876
# 661 - El friend 491341876 tiene 1188 friends
# Friend --------->30954925
# 662 - El friend 30954925 tiene 4 friends
# Friend --------->1538759678
# 663 - El friend 1538759678 tiene 427 friends
# Friend --------->712470960536813568
# 664 - El friend 712470960536813568 tiene 550 friends
# Friend --------->712685130
# 665 - El friend 712685130 tiene 1292 friends
# Friend --------->4528803987
# 666 - El friend 4528803987 tiene 881 friends
# Friend --------->474773670
# 667 - El friend 474773670 tiene 4470 friends
# Friend --------->2857471486
# 668 - El friend 2857471486 tiene 1684 friends
# Friend --------->3317031946
# 669 - El friend 3317031946 tiene 1693 friends
# Friend --------->823251820004909057
# 670 - El friend 823251820004909057 tiene 1116 friends
# Friend --------->1578141
# 671 - El friend 1578141 tiene 1703 friends
# Friend --------->2694452875
# 672 - El friend 2694452875 tiene 386 friends
# Friend --------->63873759
# Rate limit reached. Sleeping for: 887
# 673 - El friend 63873759 tiene 114 friends
# Friend --------->259624663
# 674 - El friend 259624663 tiene 52 friends
# Friend --------->2473771957
# 675 - El friend 2473771957 tiene 161 friends
# Friend --------->14337718
# 676 - El friend 14337718 tiene 2816 friends
# Friend --------->38381308
# 677 - El friend 38381308 tiene 517 friends
# Friend --------->296197591
# 678 - El friend 296197591 tiene 1555 friends
# Friend --------->88764677
# 679 - El friend 88764677 tiene 71 friends
# Friend --------->416238789
# 680 - El friend 416238789 tiene 102 friends
# Friend --------->3055688693
# 681 - El friend 3055688693 tiene 436 friends
# Friend --------->4674421753
# 682 - El friend 4674421753 tiene 2105 friends
# Friend --------->2297050399
# 683 - El friend 2297050399 tiene 952 friends
# Friend --------->1201937443
# 684 - El friend 1201937443 tiene 750 friends
# Friend --------->778630028
# 685 - El friend 778630028 tiene 1353 friends
# Friend --------->93375462
# 686 - El friend 93375462 tiene 526 friends
# Friend --------->2396192268
# 687 - El friend 2396192268 tiene 1881 friends
# Friend --------->1466876120
# Rate limit reached. Sleeping for: 887
# 688 - El friend 1466876120 tiene 1695 friends
# Friend --------->3013365358
# 689 - El friend 3013365358 tiene 140 friends
# Friend --------->2201055433
# 690 - El friend 2201055433 tiene 12 friends
# Friend --------->722459214279548928
# 691 - El friend 722459214279548928 tiene 346 friends
# Friend --------->295608887
# 692 - El friend 295608887 tiene 265 friends
# Friend --------->718232222
# 693 - El friend 718232222 tiene 258 friends
# Friend --------->4134255287
# 694 - El friend 4134255287 tiene 478 friends
# Friend --------->5554
# 695 - El friend 5554 tiene 442 friends
# Friend --------->122538868
# 696 - El friend 122538868 tiene 844 friends
# Friend --------->1448046859
# 697 - El friend 1448046859 tiene 467 friends
# Friend --------->126889049
# 698 - El friend 126889049 tiene 5414 friends
# Friend --------->144820861
# 699 - El friend 144820861 tiene 653 friends
# Friend --------->14607140
# 700 - El friend 14607140 tiene 2304 friends
# Friend --------->4134016874
# 701 - El friend 4134016874 tiene 862 friends
# Friend --------->1559868710
# Rate limit reached. Sleeping for: 887
# 702 - El friend 1559868710 tiene 78 friends
# Friend --------->716813845
# 703 - El friend 716813845 tiene 515 friends
# Friend --------->2958668424
# 704 - El friend 2958668424 tiene 113 friends
# Friend --------->2802797885
# 705 - El friend 2802797885 tiene 1046 friends
# Friend --------->312963709
# 706 - El friend 312963709 tiene 1880 friends
# Friend --------->66116319
# 707 - El friend 66116319 tiene 500 friends
# Friend --------->1473686120
# 708 - El friend 1473686120 tiene 4353 friends
# Friend --------->2611897238
# 709 - El friend 2611897238 tiene 402 friends
# Friend --------->115650900
# 710 - El friend 115650900 tiene 1976 friends
# Friend --------->24156855
# 711 - El friend 24156855 tiene 532 friends
# Friend --------->21658774
# 712 - El friend 21658774 tiene 2872 friends
# Friend --------->16351266
# 713 - El friend 16351266 tiene 336 friends
# Friend --------->13613292
# 714 - El friend 13613292 tiene 1525 friends
# Friend --------->1525669423
# 715 - El friend 1525669423 tiene 3660 friends
# Friend --------->138475538
# Rate limit reached. Sleeping for: 886
# 716 - El friend 138475538 tiene 16708 friends
# Friend --------->767285
# 717 - El friend 767285 tiene 1140 friends
# Friend --------->287789516
# 718 - El friend 287789516 tiene 833 friends
# Friend --------->70520806
# 719 - El friend 70520806 tiene 746 friends
# Friend --------->9600442
# 720 - El friend 9600442 tiene 802 friends
# Friend --------->59091469
# 721 - El friend 59091469 tiene 1425 friends
# Friend --------->15649433
# 722 - El friend 15649433 tiene 571 friends
# Friend --------->43218848
# 723 - El friend 43218848 tiene 2365 friends
# Friend --------->302666251
# 724 - El friend 302666251 tiene 983 friends
# Friend --------->17877351
# 725 - El friend 17877351 tiene 356 friends
# Friend --------->314478070
# 726 - El friend 314478070 tiene 289 friends
# Friend --------->188683472
# 727 - El friend 188683472 tiene 109 friends
# Friend --------->303673201
# 728 - El friend 303673201 tiene 614 friends
# Friend --------->91781128
# Rate limit reached. Sleeping for: 886
# 729 - El friend 91781128 tiene 507 friends
# Friend --------->266400754
# 730 - El friend 266400754 tiene 368 friends
# Friend --------->331514947
# 731 - El friend 331514947 tiene 423 friends
# Friend --------->119026419
# 732 - El friend 119026419 tiene 2207 friends
# Friend --------->229215024
# 733 - El friend 229215024 tiene 341 friends
# Friend --------->23791197
# 734 - El friend 23791197 tiene 0 friends
# Friend --------->231000704
# 735 - El friend 231000704 tiene 5241 friends
# Friend --------->85380154
# 736 - El friend 85380154 tiene 453 friends
# Friend --------->64721604
# 737 - El friend 64721604 tiene 303 friends
# Friend --------->161997267
# 738 - El friend 161997267 tiene 365 friends
# Friend --------->205161710
# 739 - El friend 205161710 tiene 537 friends
# Friend --------->376064496
# 740 - El friend 376064496 tiene 224 friends
# Friend --------->15581283
# 741 - El friend 15581283 tiene 1301 friends
# Friend --------->14274452
# 742 - El friend 14274452 tiene 530 friends
# Friend --------->188367161
# Rate limit reached. Sleeping for: 888
# 743 - El friend 188367161 tiene 161 friends
# Friend --------->50665193
# 744 - El friend 50665193 tiene 193 friends
# Friend --------->31441365
# 745 - El friend 31441365 tiene 4400 friends
# Friend --------->80016691
# 746 - El friend 80016691 tiene 2097 friends

# %%
len(followers_d)
len(friends_d)
# Out:
# 746

# %%
#almaceno los datos
datos_friends = []
for user_id in friends_d:
    for friend_id in friends_d[user_id]:
        enlace={'orig':user_id,
               'dest':friend_id}
        datos.append(enlace)
        datos_friends.append(enlace)
        #print(user_id,follower_id)

len(datos)
len(datos_friends)
df_todo = pd.DataFrame(datos)
df_friends = pd.DataFrame(datos_friends)
df_todo.info()
df_friends.info()

df_todo.to_csv('grafo_jecrespom.csv',sep=' ',index=False,header=False)
df_friends.to_csv('grafo_friends.csv',sep=' ',index=False,header=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1645507 entries, 0 to 1645506
# Data columns (total 2 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   orig    1645507 non-null  int64
#  1   dest    1645507 non-null  int64
# dtypes: int64(2)
# memory usage: 25.1 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1080783 entries, 0 to 1080782
# Data columns (total 2 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   orig    1080783 non-null  int64
#  1   dest    1080783 non-null  int64
# dtypes: int64(2)
# memory usage: 16.5 MB

# %%
#continuar cogiendo datos de followers
import pandas as pd
followers = api.followers_ids('jecrespom')
print(len(followers))

df_followers_csv=pd.read_csv('grafo_followers.csv',sep=' ',header=None)

print(df_followers_csv.describe())
print(df_followers_csv)
df_followers_csv.info()
# Out:
# 2600
#                   0             1
# count  5.647240e+05  5.647240e+05
# mean   1.551796e+17  2.098132e+17
# std    3.553249e+17  3.995839e+17
# min    9.399452e+06  2.200000e+01
# 25%    1.507584e+08  2.641499e+08
# 50%    1.075911e+09  1.193966e+09
# 75%    2.758682e+09  4.061520e+09
# max    1.258423e+18  1.268636e+18
#                  0           1
# 0       1138115772   189292089
# 1       1138115772   106205259
# 2       1138115772  1344677880
# 3       1138115772  3384981329
# 4       1138115772  3081302315
# ...            ...         ...
# 564719  1048477987   113306870
# 564720  1048477987   267342797
# 564721  1048477987   130885134
# 564722  1048477987   465684445
# 564723  1048477987   507863116
#
# [564724 rows x 2 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 564724 entries, 0 to 564723
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   0       564724 non-null  int64
#  1   1       564724 non-null  int64
# dtypes: int64(2)
# memory usage: 8.6 MB

# %%
#followers ya revisados
df_followers_csv[0].unique()
followers_csv = list(df_followers_csv[0].unique())
len(followers_csv)
# Out:
# 514

# %%
#continuo tomando followers que no estén en followers_csv.
#mejor hacer una función
followers_d = {}
acceso_no_permitido = []
n = 0 #consultas a la api para followers
for follower_id in followers:
    if follower_id in followers_csv:
        print(f'El usuario {follower_id} está en el csv')
        continue
    
    if follower_id in followers_d:
        print(f'El usuario {follower_id} ya se ha descargado')
        continue
    
    if follower_id in acceso_no_permitido:
        print(f'El usuario {follower_id} se ha marcado para no acceder a sus datos')
        continue
    
    print(f'Follower --------->{follower_id}')
    followers_d[follower_id] = [] #lista de follower de mi follower
    
    try:
        n+=1
        for followers_hijo in tweepy.Cursor(api.followers_ids,follower_id).items(300000):
            followers_d[follower_id].append(followers_hijo)
            
        print(f'{n} - El follower {follower_id} tiene {len(followers_d[follower_id])} seguidores')
    except tweepy.TweepError as e:
        if 'Not authorized' in str(e):
            print(f'{n} - El usuario {follower_id} no nos deja acceder a sus datos')
            acceso_no_permitido.append(follower_id)
        else:
            print(e)
            time.sleep(60)
# Out:
# El usuario 1138115772 está en el csv
# El usuario 867052638873022464 está en el csv
# El usuario 93147038 está en el csv
# El usuario 3298925390 está en el csv
# Follower --------->848918106
# Rate limit reached. Sleeping for: 645
# 1 - El usuario 848918106 no nos deja acceder a sus datos
# Follower --------->1648904448
# 2 - El usuario 1648904448 no nos deja acceder a sus datos
# El usuario 1258422929295056903 está en el csv
# El usuario 795938924489281536 está en el csv
# El usuario 63600623 está en el csv
# El usuario 1254739233459376129 está en el csv
# El usuario 1203014081566969858 está en el csv
# Follower --------->2738058851
# 3 - El usuario 2738058851 no nos deja acceder a sus datos
# El usuario 207158301 está en el csv
# El usuario 910954837 está en el csv
# El usuario 269006291 está en el csv
# El usuario 1226064262709334016 está en el csv
# El usuario 1142076991455289351 está en el csv
# El usuario 107189419 está en el csv
# El usuario 271178681 está en el csv
# Follower --------->406596269
# 4 - El usuario 406596269 no nos deja acceder a sus datos
# El usuario 1077604505401913344 está en el csv
# El usuario 1071698929 está en el csv
# El usuario 315765618 está en el csv
# El usuario 971178019590205440 está en el csv
# El usuario 335359705 está en el csv
# El usuario 955923421 está en el csv
# El usuario 1661110783 está en el csv
# El usuario 933765574982885376 está en el csv
# Follower --------->970438251189239808
# 5 - El follower 970438251189239808 tiene 74 seguidores
# El usuario 3253367533 está en el csv
# El usuario 974998462101106688 está en el csv
# El usuario 3319318173 está en el csv
# El usuario 93881212 está en el csv
# El usuario 192897149 está en el csv
# El usuario 1242800864005443584 está en el csv
# El usuario 1240688968808701953 está en el csv
# El usuario 2212461865 está en el csv
# El usuario 1118927846678958085 está en el csv
# El usuario 724669800748818432 está en el csv
# El usuario 1086733250498908160 está en el csv
# El usuario 338603142 está en el csv
# El usuario 9399452 está en el csv
# El usuario 1229162687218712578 está en el csv
# El usuario 1240379998940389379 está en el csv
# Follower --------->1014114645047758848
# 6 - El follower 1014114645047758848 tiene 129 seguidores
# Follower --------->1231089713408348161
# 7 - El usuario 1231089713408348161 no nos deja acceder a sus datos
# El usuario 3105980830 está en el csv
# El usuario 1160231561507291136 está en el csv
# El usuario 728137388 está en el csv
# El usuario 172801059 está en el csv
# El usuario 61169476 está en el csv
# El usuario 18474421 está en el csv
# El usuario 60152351 está en el csv
# El usuario 266197553 está en el csv
# El usuario 701018446704803840 está en el csv
# El usuario 917968321 está en el csv
# El usuario 3288081239 está en el csv
# El usuario 3919851418 está en el csv
# El usuario 1173624533636583424 está en el csv
# El usuario 19412575 está en el csv
# Follower --------->1226677471929495555
# 8 - El usuario 1226677471929495555 no nos deja acceder a sus datos
# El usuario 896665173657886721 está en el csv
# El usuario 783287228 está en el csv
# El usuario 308451924 está en el csv
# El usuario 1228728758883909632 está en el csv
# El usuario 864804906317819904 está en el csv
# El usuario 887644903077019648 está en el csv
# El usuario 1218127790106648576 está en el csv
# El usuario 1102699144496451586 está en el csv
# Follower --------->2578600342
# 9 - El usuario 2578600342 no nos deja acceder a sus datos
# Follower --------->1119303015729651712
# 10 - El usuario 1119303015729651712 no nos deja acceder a sus datos
# El usuario 3228488541 está en el csv
# El usuario 826855556979761152 está en el csv
# El usuario 986219887088500736 está en el csv
# El usuario 838724315545743361 está en el csv
# El usuario 1216491224166731777 está en el csv
# El usuario 1009074100436946946 está en el csv
# El usuario 1222812088407674881 está en el csv
# El usuario 970989441421594624 está en el csv
# El usuario 1096215827106463744 está en el csv
# El usuario 229939190 está en el csv
# El usuario 1220356864417943554 está en el csv
# El usuario 1108494962885382144 está en el csv
# El usuario 802453710584639488 está en el csv
# Follower --------->2871199970
# 11 - El usuario 2871199970 no nos deja acceder a sus datos
# Follower --------->17675782
# 12 - El usuario 17675782 no nos deja acceder a sus datos
# El usuario 91853816 está en el csv
# El usuario 1920151681 está en el csv
# Follower --------->75504143
# 13 - El usuario 75504143 no nos deja acceder a sus datos
# El usuario 1183781521423044609 está en el csv
# El usuario 279884520 está en el csv
# El usuario 240850305 está en el csv
# El usuario 958592125238763520 está en el csv
# El usuario 14597867 está en el csv
# El usuario 1179760149952679941 está en el csv
# El usuario 268635695 está en el csv
# Follower --------->172869037
# 14 - El usuario 172869037 no nos deja acceder a sus datos
# El usuario 976188704757895168 está en el csv
# El usuario 1207617029118840839 está en el csv
# El usuario 835865257088274432 está en el csv
# El usuario 861581623543967745 está en el csv
# El usuario 1149975272990617600 está en el csv
# Follower --------->2272072375
# 15 - El follower 2272072375 tiene 43 seguidores
# El usuario 908137150037872642 está en el csv
# El usuario 3612606694 está en el csv
# El usuario 4795451909 está en el csv
# El usuario 266897100 está en el csv
# El usuario 1419298866 está en el csv
# El usuario 728382570249981952 está en el csv
# El usuario 1103400885475004416 está en el csv
# El usuario 288413387 está en el csv
# El usuario 1186937974434553856 está en el csv
# El usuario 1122988172969951233 está en el csv
# El usuario 965711714108035073 está en el csv
# El usuario 1138539255163228160 está en el csv
# El usuario 3375591226 está en el csv
# El usuario 1185965170029420544 está en el csv
# El usuario 1189514475977805826 está en el csv
# El usuario 1164895859936563200 está en el csv
# El usuario 589922921 está en el csv
# El usuario 208757743 está en el csv
# Follower --------->469593822
# Rate limit reached. Sleeping for: 888
# 16 - El usuario 469593822 no nos deja acceder a sus datos
# El usuario 17972582 está en el csv
# El usuario 150758393 está en el csv
# El usuario 140349661 está en el csv
# El usuario 2159632612 está en el csv
# El usuario 566556394 está en el csv
# El usuario 49020441 está en el csv
# El usuario 152188854 está en el csv
# El usuario 986347244713664512 está en el csv
# El usuario 266206630 está en el csv
# El usuario 4786360043 está en el csv
# El usuario 260611316 está en el csv
# Follower --------->1174444865897345024
# 17 - El follower 1174444865897345024 tiene 17 seguidores
# El usuario 95217936 está en el csv
# Follower --------->619810936
# 18 - El usuario 619810936 no nos deja acceder a sus datos
# El usuario 3003151337 está en el csv
# El usuario 1158930019009335296 está en el csv
# El usuario 2417269134 está en el csv
# El usuario 1119980084440510465 está en el csv
# El usuario 4866855484 está en el csv
# El usuario 1083448355349397504 está en el csv
# El usuario 495157183 está en el csv
# El usuario 522343669 está en el csv
# El usuario 269995742 está en el csv
# El usuario 14456775 está en el csv
# El usuario 1171482015641718788 está en el csv
# El usuario 749461133111791616 está en el csv
# El usuario 49126592 está en el csv
# El usuario 292217941 está en el csv
# El usuario 410633493 está en el csv
# El usuario 1121705314473082880 está en el csv
# El usuario 272628940 está en el csv
# El usuario 789595098174685184 está en el csv
# El usuario 917711055937331205 está en el csv
# El usuario 96730899 está en el csv
# El usuario 324857822 está en el csv
# El usuario 1075468808108814338 está en el csv
# El usuario 144801834 está en el csv
# El usuario 22947082 está en el csv
# El usuario 188300159 está en el csv
# El usuario 972467273012260864 está en el csv
# El usuario 274592041 está en el csv
# El usuario 2428806922 está en el csv
# El usuario 75495576 está en el csv
# El usuario 295100886 está en el csv
# El usuario 1075910966 está en el csv
# El usuario 230418390 está en el csv
# El usuario 235346355 está en el csv
# El usuario 43210905 está en el csv
# El usuario 12339482 está en el csv
# El usuario 1379795863 está en el csv
# El usuario 369247037 está en el csv
# El usuario 1098874382980730880 está en el csv
# El usuario 385462306 está en el csv
# El usuario 883598688 está en el csv
# El usuario 1922819430 está en el csv
# El usuario 1345030855 está en el csv
# El usuario 126602043 está en el csv
# El usuario 267078766 está en el csv
# El usuario 536435650 está en el csv
# El usuario 2520691851 está en el csv
# El usuario 1951680043 está en el csv
# El usuario 748930737307525120 está en el csv
# El usuario 1172470300979671040 está en el csv
# El usuario 911168364923555840 está en el csv
# El usuario 1103759076692017152 está en el csv
# El usuario 67359755 está en el csv
# El usuario 882529980038750210 está en el csv
# El usuario 95485591 está en el csv
# El usuario 1005220705 está en el csv
# El usuario 417095907 está en el csv
# El usuario 769264026 está en el csv
# El usuario 2802260702 está en el csv
# Follower --------->604756193
# 19 - El usuario 604756193 no nos deja acceder a sus datos
# El usuario 1110561380598538240 está en el csv
# El usuario 1157010722599161858 está en el csv
# Follower --------->856195997600501762
# 20 - El follower 856195997600501762 tiene 0 seguidores
# El usuario 977352185435578368 está en el csv
# Follower --------->423969547
# 21 - El usuario 423969547 no nos deja acceder a sus datos
# El usuario 3384126153 está en el csv
# El usuario 2267192342 está en el csv
# El usuario 891216939443527680 está en el csv
# El usuario 1136907122900439043 está en el csv
# El usuario 49231477 está en el csv
# El usuario 106495340 está en el csv
# El usuario 232341589 está en el csv
# El usuario 206451237 está en el csv
# Follower --------->627670338
# 22 - El usuario 627670338 no nos deja acceder a sus datos
# El usuario 52290247 está en el csv
# El usuario 2550679345 está en el csv
# El usuario 172859440 está en el csv
# El usuario 1155897630830055431 está en el csv
# El usuario 927474757003603968 está en el csv
# El usuario 2832195031 está en el csv
# El usuario 326264713 está en el csv
# El usuario 918841282197426176 está en el csv
# El usuario 55351126 está en el csv
# El usuario 261227398 está en el csv
# El usuario 931009980 está en el csv
# El usuario 776129038901473280 está en el csv
# El usuario 919705495933476865 está en el csv
# El usuario 1146799924455137281 está en el csv
# Follower --------->1033317343
# 23 - El usuario 1033317343 no nos deja acceder a sus datos
# El usuario 920592878895796224 está en el csv
# El usuario 1139683732682657792 está en el csv
# El usuario 14260921 está en el csv
# El usuario 253930986 está en el csv
# El usuario 267397452 está en el csv
# El usuario 211394459 está en el csv
# El usuario 2701994590 está en el csv
# El usuario 220553332 está en el csv
# El usuario 469414032 está en el csv
# El usuario 4158797301 está en el csv
# El usuario 80175900 está en el csv
# El usuario 102862880 está en el csv
# El usuario 872117755 está en el csv
# El usuario 1093302924313325570 está en el csv
# El usuario 36495364 está en el csv
# El usuario 789291739 está en el csv
# El usuario 3296651076 está en el csv
# El usuario 1122917205857918977 está en el csv
# El usuario 167116491 está en el csv
# El usuario 900791472643084293 está en el csv
# El usuario 2596552676 está en el csv
# Follower --------->1055182915863281672
# 24 - El usuario 1055182915863281672 no nos deja acceder a sus datos
# El usuario 1129342804344397825 está en el csv
# El usuario 2775364786 está en el csv
# El usuario 4737947385 está en el csv
# El usuario 302772644 está en el csv
# El usuario 2445525426 está en el csv
# Follower --------->16947418
# 25 - El usuario 16947418 no nos deja acceder a sus datos
# El usuario 1261295371 está en el csv
# Follower --------->1099413063873245186
# 26 - El follower 1099413063873245186 tiene 0 seguidores
# Follower --------->134829365
# 27 - El usuario 134829365 no nos deja acceder a sus datos
# El usuario 1062483629886988288 está en el csv
# Follower --------->303642532
# Rate limit reached. Sleeping for: 889
# 28 - El usuario 303642532 no nos deja acceder a sus datos
# El usuario 22681195 está en el csv
# El usuario 962367276606423040 está en el csv
# El usuario 104745672 está en el csv
# El usuario 383934253 está en el csv
# El usuario 1715967223 está en el csv
# El usuario 318993513 está en el csv
# El usuario 2317390682 está en el csv
# El usuario 924401311906451462 está en el csv
# El usuario 343382124 está en el csv
# El usuario 1357992950 está en el csv
# El usuario 357163894 está en el csv
# El usuario 99809517 está en el csv
# Follower --------->899808815910191104
# 29 - El follower 899808815910191104 tiene 2 seguidores
# El usuario 134447383 está en el csv
# El usuario 1098972648128811014 está en el csv
# El usuario 1112074444724416513 está en el csv
# El usuario 857616032189612032 está en el csv
# El usuario 1120187355128840193 está en el csv
# Follower --------->1120248078685044736
# 30 - El follower 1120248078685044736 tiene 0 seguidores
# Follower --------->795728197711261698
# 31 - El usuario 795728197711261698 no nos deja acceder a sus datos
# El usuario 1283468348 está en el csv
# El usuario 1084777902380584960 está en el csv
# El usuario 728823018 está en el csv
# El usuario 1105031494282690561 está en el csv
# El usuario 234272472 está en el csv
# El usuario 334078686 está en el csv
# El usuario 327476251 está en el csv
# El usuario 260469342 está en el csv
# Follower --------->778151873803067392
# 32 - El follower 778151873803067392 tiene 902 seguidores
# El usuario 3299519009 está en el csv
# Follower --------->2360179226
# 33 - El usuario 2360179226 no nos deja acceder a sus datos
# El usuario 61330962 está en el csv
# El usuario 253939528 está en el csv
# El usuario 415237850 está en el csv
# El usuario 911773067671719936 está en el csv
# El usuario 732831114201583617 está en el csv
# El usuario 2810290568 está en el csv
# El usuario 1905000438 está en el csv
# El usuario 2458754380 está en el csv
# El usuario 217591820 está en el csv
# El usuario 881986786502860801 está en el csv
# El usuario 970019166559391745 está en el csv
# El usuario 636548071 está en el csv
# El usuario 4879324121 está en el csv
# El usuario 2787431048 está en el csv
# El usuario 863604703 está en el csv
# El usuario 199221680 está en el csv
# El usuario 940911512599912448 está en el csv
# El usuario 1099986658387202051 está en el csv
# El usuario 15596151 está en el csv
# El usuario 1109007074569216001 está en el csv
# El usuario 825043520 está en el csv
# El usuario 880285183 está en el csv
# Follower --------->979932248
# 34 - El usuario 979932248 no nos deja acceder a sus datos
# El usuario 565605430 está en el csv
# El usuario 856746497987268608 está en el csv
# El usuario 725372220583862279 está en el csv
# El usuario 1082751622797819906 está en el csv
# El usuario 797901439267913728 está en el csv
# El usuario 786588345585500160 está en el csv
# El usuario 748390947759788032 está en el csv
# El usuario 727521538468118528 está en el csv
# Follower --------->335296044
# 35 - El usuario 335296044 no nos deja acceder a sus datos
# Follower --------->919674252160372736
# 36 - El follower 919674252160372736 tiene 0 seguidores
# El usuario 1055544750630191104 está en el csv
# El usuario 1105466720838397952 está en el csv
# El usuario 74294867 está en el csv
# El usuario 17053937 está en el csv
# El usuario 386051947 está en el csv
# El usuario 338259207 está en el csv
# Follower --------->197467245
# 37 - El follower 197467245 tiene 816 seguidores
# El usuario 4850154322 está en el csv
# El usuario 2972907299 está en el csv
# Follower --------->181570574
# 38 - El usuario 181570574 no nos deja acceder a sus datos
# El usuario 3344035072 está en el csv
# El usuario 439293707 está en el csv
# El usuario 846351350 está en el csv
# El usuario 3226938653 está en el csv
# El usuario 291894534 está en el csv
# El usuario 82632187 está en el csv
# El usuario 911363290642702339 está en el csv
# El usuario 3688337415 está en el csv
# El usuario 14135101 está en el csv
# El usuario 389688115 está en el csv
# El usuario 85976127 está en el csv
# El usuario 195841105 está en el csv
# El usuario 1101836495391023110 está en el csv
# El usuario 730224774987845638 está en el csv
# El usuario 1713153726 está en el csv
# El usuario 4850101264 está en el csv
# El usuario 122455228 está en el csv
# El usuario 17732795 está en el csv
# El usuario 833077330360807425 está en el csv
# El usuario 3010608918 está en el csv
# El usuario 1057561806477189120 está en el csv
# El usuario 207957856 está en el csv
# El usuario 397216608 está en el csv
# El usuario 1037086252049334273 está en el csv
# Follower --------->217441025
# 39 - El follower 217441025 tiene 124 seguidores
# Follower --------->2984485426
# 40 - El follower 2984485426 tiene 0 seguidores
# El usuario 1065046646373920770 está en el csv
# El usuario 4118905558 está en el csv
# El usuario 306785937 está en el csv
# El usuario 1438732669 está en el csv
# El usuario 137678406 está en el csv
# El usuario 1085722231278354432 está en el csv
# El usuario 2344612990 está en el csv
# El usuario 1093410452237881344 está en el csv
# El usuario 15837083 está en el csv
# El usuario 1071933176434622464 está en el csv
# El usuario 1093180544236564482 está en el csv
# El usuario 187342941 está en el csv
# El usuario 508697101 está en el csv
# El usuario 1033648956499222528 está en el csv
# El usuario 2434904682 está en el csv
# El usuario 1084771371329175552 está en el csv
# El usuario 120605790 está en el csv
# El usuario 137467666 está en el csv
# El usuario 3295849528 está en el csv
# El usuario 977952164 está en el csv
# El usuario 1062685860087414784 está en el csv
# El usuario 17863599 está en el csv
# El usuario 913054949055090688 está en el csv
# El usuario 1488460416 está en el csv
# El usuario 873734975258062848 está en el csv
# El usuario 1279400059 está en el csv
# El usuario 4032131295 está en el csv
# El usuario 980846595737640965 está en el csv
# El usuario 474773670 está en el csv
# El usuario 1081581217462603778 está en el csv
# El usuario 1039331765792456704 está en el csv
# El usuario 192522831 está en el csv
# Follower --------->1072598912832286721
# Rate limit reached. Sleeping for: 890
# 41 - El follower 1072598912832286721 tiene 0 seguidores
# El usuario 405804727 está en el csv
# El usuario 939980077571420167 está en el csv
# El usuario 1355086945 está en el csv
# El usuario 249007164 está en el csv
# El usuario 1064521106554568704 está en el csv
# El usuario 1343876654 está en el csv
# El usuario 1201937443 está en el csv
# El usuario 2838287115 está en el csv
# El usuario 133551258 está en el csv
# El usuario 3842288955 está en el csv
# El usuario 987734660267565056 está en el csv
# El usuario 12892032 está en el csv
# El usuario 3665813129 está en el csv
# El usuario 217589494 está en el csv
# El usuario 1078308789592444928 está en el csv
# El usuario 1193595097 está en el csv
# Follower --------->75342656
# 42 - El follower 75342656 tiene 0 seguidores
# Follower --------->772119574833664000
# 43 - El usuario 772119574833664000 no nos deja acceder a sus datos
# Follower --------->775627917330186240
# 44 - El usuario 775627917330186240 no nos deja acceder a sus datos
# El usuario 1027178417844887552 está en el csv
# El usuario 2347208693 está en el csv
# El usuario 3298765342 está en el csv
# El usuario 416238789 está en el csv
# El usuario 1073670803869351939 está en el csv
# El usuario 309617530 está en el csv
# El usuario 114516439 está en el csv
# El usuario 3218859202 está en el csv
# El usuario 883437419693047808 está en el csv
# El usuario 227056307 está en el csv
# El usuario 2952874306 está en el csv
# Follower --------->2912528287
# 45 - El usuario 2912528287 no nos deja acceder a sus datos
# El usuario 187653310 está en el csv
# El usuario 86998264 está en el csv
# El usuario 82894804 está en el csv
# El usuario 338500666 está en el csv
# El usuario 132333002 está en el csv
# El usuario 2955195436 está en el csv
# El usuario 1355772038 está en el csv
# El usuario 792452013871300608 está en el csv
# El usuario 1064107576349130752 está en el csv
# El usuario 2824948678 está en el csv
# El usuario 821439972645498883 está en el csv
# El usuario 89283858 está en el csv
# El usuario 980236683852636160 está en el csv
# Follower --------->498141500
# 46 - El follower 498141500 tiene 7 seguidores
# Follower --------->2707431362
# 47 - El follower 2707431362 tiene 71 seguidores
# Follower --------->132851687
# 48 - El follower 132851687 tiene 3126 seguidores
# Follower --------->155089809
# 49 - El follower 155089809 tiene 686 seguidores
# Follower --------->962774296916570112
# 50 - El follower 962774296916570112 tiene 1 seguidores
# El usuario 728143654636822530 está en el csv
# El usuario 971796017543897088 está en el csv
# El usuario 2844374418 está en el csv
# Follower --------->95082328
# 51 - El usuario 95082328 no nos deja acceder a sus datos
# El usuario 1057017067331862528 está en el csv
# Follower --------->1058871466220052481
# 52 - El follower 1058871466220052481 tiene 0 seguidores
# Follower --------->722878931943235584
# 53 - El usuario 722878931943235584 no nos deja acceder a sus datos
# Follower --------->762319792695042048
# 54 - El usuario 762319792695042048 no nos deja acceder a sus datos
# El usuario 236948620 está en el csv
# Follower --------->405873374
# 55 - El usuario 405873374 no nos deja acceder a sus datos
# El usuario 992245872569143296 está en el csv
# El usuario 1060603082940313600 está en el csv
# El usuario 214032261 está en el csv
# El usuario 1620461760 está en el csv
# Follower --------->1680276368
# Rate limit reached. Sleeping for: 887
# 56 - El usuario 1680276368 no nos deja acceder a sus datos
# El usuario 3403757997 está en el csv
# El usuario 931823923 está en el csv
# El usuario 760800617485008896 está en el csv
# El usuario 742332951766130688 está en el csv
# El usuario 501017681 está en el csv
# El usuario 888201341583196160 está en el csv
# El usuario 166660272 está en el csv
# El usuario 270079528 está en el csv
# El usuario 1286558558 está en el csv
# Follower --------->159543688
# 57 - El usuario 159543688 no nos deja acceder a sus datos
# El usuario 2153573971 está en el csv
# El usuario 346911652 está en el csv
# El usuario 302702997 está en el csv
# El usuario 829957221673029633 está en el csv
# El usuario 501593883 está en el csv
# El usuario 3074246214 está en el csv
# El usuario 3028533922 está en el csv
# El usuario 53765207 está en el csv
# El usuario 998282257097019392 está en el csv
# El usuario 134752238 está en el csv
# El usuario 40682496 está en el csv
# El usuario 1042493594362368001 está en el csv
# El usuario 2758681690 está en el csv
# El usuario 147623875 está en el csv
# Follower --------->822979828525727745
# 58 - El follower 822979828525727745 tiene 132 seguidores
# Follower --------->1299894949
# 59 - El follower 1299894949 tiene 228 seguidores
# Follower --------->245829098
# 60 - El follower 245829098 tiene 391 seguidores
# Follower --------->59091469
# 61 - El follower 59091469 tiene 2474 seguidores
# Follower --------->88478189
# 62 - El usuario 88478189 no nos deja acceder a sus datos
# El usuario 2849579134 está en el csv
# El usuario 21246129 está en el csv
# El usuario 2930672915 está en el csv
# El usuario 66152031 está en el csv
# Follower --------->212202239
# 63 - El follower 212202239 tiene 0 seguidores
# El usuario 153900004 está en el csv
# El usuario 2425863594 está en el csv
# El usuario 311096609 está en el csv
# El usuario 338183663 está en el csv
# El usuario 4217524895 está en el csv
# El usuario 1851537871 está en el csv
# El usuario 770637060713619456 está en el csv
# El usuario 946270217851756545 está en el csv
# El usuario 875343013 está en el csv
# El usuario 254179441 está en el csv
# El usuario 985196746950299649 está en el csv
# El usuario 846907875423404032 está en el csv
# El usuario 876784384703115264 está en el csv
# El usuario 17283179 está en el csv
# El usuario 361534233 está en el csv
# El usuario 1630407859 está en el csv
# El usuario 778528320 está en el csv
# Follower --------->486853972
# 64 - El usuario 486853972 no nos deja acceder a sus datos
# El usuario 2839111439 está en el csv
# El usuario 313606237 está en el csv
# Follower --------->824234931681394688
# 65 - El usuario 824234931681394688 no nos deja acceder a sus datos
# El usuario 974784707098529792 está en el csv
# El usuario 928456461180686338 está en el csv
# El usuario 2268654205 está en el csv
# Follower --------->312087868
# 66 - El usuario 312087868 no nos deja acceder a sus datos
# Follower --------->321786509
# 67 - El follower 321786509 tiene 208 seguidores
# El usuario 847474554712711168 está en el csv
# El usuario 4254567554 está en el csv
# El usuario 629722660 está en el csv
# El usuario 18585064 está en el csv
# El usuario 2644025974 está en el csv
# El usuario 2387687005 está en el csv
# El usuario 444569080 está en el csv
# El usuario 503585923 está en el csv
# El usuario 772728159338917888 está en el csv
# Follower --------->65629661
# 68 - El usuario 65629661 no nos deja acceder a sus datos
# El usuario 129851094 está en el csv
# El usuario 250405612 está en el csv
# El usuario 143078777 está en el csv
# Follower --------->2934106375
# 69 - El usuario 2934106375 no nos deja acceder a sus datos
# Follower --------->788111524858568704
# 70 - El follower 788111524858568704 tiene 0 seguidores
# Follower --------->4031559133
# Rate limit reached. Sleeping for: 889
# 71 - El usuario 4031559133 no nos deja acceder a sus datos
# El usuario 92531108 está en el csv
# El usuario 478294829 está en el csv
# El usuario 274617138 está en el csv
# El usuario 275210909 está en el csv
# El usuario 877095327223996416 está en el csv
# El usuario 989063436733730816 está en el csv
# El usuario 980672549427208192 está en el csv
# El usuario 359934608 está en el csv
# El usuario 1000303340209823745 está en el csv
# El usuario 3073746006 está en el csv
# El usuario 2885633817 está en el csv
# Follower --------->141696758
# 72 - El usuario 141696758 no nos deja acceder a sus datos
# El usuario 81739441 está en el csv
# El usuario 334076268 está en el csv
# El usuario 83629804 está en el csv
# El usuario 15286966 está en el csv
# El usuario 433389093 está en el csv
# El usuario 1004726897203392512 está en el csv
# El usuario 95532625 está en el csv
# El usuario 32333402 está en el csv
# El usuario 1308323742 está en el csv
# El usuario 384928466 está en el csv
# Follower --------->290143710
# 73 - El usuario 290143710 no nos deja acceder a sus datos
# El usuario 937592982 está en el csv
# El usuario 976902682224091136 está en el csv
# El usuario 4834855665 está en el csv
# El usuario 796020377076060160 está en el csv
# Follower --------->232391945
# 74 - El usuario 232391945 no nos deja acceder a sus datos
# El usuario 1004700454775934977 está en el csv
# Follower --------->210938172
# 75 - El follower 210938172 tiene 10 seguidores
# Follower --------->52102005
# 76 - El follower 52102005 tiene 18 seguidores
# El usuario 94826884 está en el csv
# El usuario 618005197 está en el csv
# Follower --------->245928972
# 77 - El usuario 245928972 no nos deja acceder a sus datos
# El usuario 1001404746228551680 está en el csv
# El usuario 144265252 está en el csv
# El usuario 621432690 está en el csv
# El usuario 4785852635 está en el csv
# El usuario 706014493852246016 está en el csv
# El usuario 558804431 está en el csv
# El usuario 997141631106199553 está en el csv
# El usuario 293870784 está en el csv
# El usuario 59905563 está en el csv
# El usuario 59133365 está en el csv
# El usuario 597568722 está en el csv
# El usuario 138330745 está en el csv
# El usuario 359051825 está en el csv
# El usuario 358336449 está en el csv
# El usuario 4333257561 está en el csv
# El usuario 196539787 está en el csv
# El usuario 307927812 está en el csv
# El usuario 4296501561 está en el csv
# El usuario 143445538 está en el csv
# El usuario 783250530 está en el csv
# El usuario 1637804689 está en el csv
# El usuario 4920782152 está en el csv
# El usuario 249070567 está en el csv
# El usuario 163791630 está en el csv
# El usuario 103857002 está en el csv
# El usuario 1048477987 está en el csv
# Follower --------->980999017
# 78 - El follower 980999017 tiene 16 seguidores
# Follower --------->808238169384767488
# 79 - El follower 808238169384767488 tiene 342 seguidores
# Follower --------->731444043486466048
# 80 - El follower 731444043486466048 tiene 724 seguidores
# Follower --------->1625516300
# 81 - El follower 1625516300 tiene 408 seguidores
# Follower --------->107799739
# 82 - El usuario 107799739 no nos deja acceder a sus datos
# Follower --------->796821652575309824
# 83 - El follower 796821652575309824 tiene 116 seguidores
# Follower --------->323823156
# 84 - El follower 323823156 tiene 23 seguidores
# Follower --------->2174585419
# 85 - El follower 2174585419 tiene 70 seguidores
# Follower --------->99082404
# Rate limit reached. Sleeping for: 889
# 86 - El follower 99082404 tiene 281 seguidores
# Follower --------->1322000982
# 87 - El usuario 1322000982 no nos deja acceder a sus datos
# Follower --------->855589520175239173
# 88 - El follower 855589520175239173 tiene 221 seguidores
# Follower --------->3181975155
# 89 - El follower 3181975155 tiene 9 seguidores
# Follower --------->490847558
# 90 - El follower 490847558 tiene 193 seguidores
# Follower --------->177916054
# 91 - El follower 177916054 tiene 1384 seguidores
# Follower --------->827988150828036098
# 92 - El usuario 827988150828036098 no nos deja acceder a sus datos
# Follower --------->2455322468
# 93 - El follower 2455322468 tiene 81 seguidores
# Follower --------->14871001
# 94 - El follower 14871001 tiene 236 seguidores
# Follower --------->897534190010474496
# 95 - El follower 897534190010474496 tiene 55 seguidores
# Follower --------->768222189980180484
# 96 - El follower 768222189980180484 tiene 750 seguidores
# Follower --------->972796188402552832
# 97 - El usuario 972796188402552832 no nos deja acceder a sus datos
# Follower --------->399441218
# 98 - El usuario 399441218 no nos deja acceder a sus datos
# Follower --------->3380118328
# 99 - El usuario 3380118328 no nos deja acceder a sus datos
# Follower --------->1297233308
# 100 - El follower 1297233308 tiene 56 seguidores
# Follower --------->87331705
# Rate limit reached. Sleeping for: 887
# 101 - El follower 87331705 tiene 130 seguidores
# Follower --------->417435251
# 102 - El follower 417435251 tiene 96 seguidores
# Follower --------->211061881
# 103 - El follower 211061881 tiene 380 seguidores
# Follower --------->975498929294008322
# 104 - El follower 975498929294008322 tiene 18 seguidores
# Follower --------->2806968349
# 105 - El follower 2806968349 tiene 100 seguidores
# Follower --------->977560604956413952
# 106 - El follower 977560604956413952 tiene 7 seguidores
# Follower --------->95934385
# 107 - El follower 95934385 tiene 87 seguidores
# Follower --------->1213575026
# 108 - El usuario 1213575026 no nos deja acceder a sus datos
# Follower --------->950660840016945152
# 109 - El follower 950660840016945152 tiene 125 seguidores
# Follower --------->167917734
# 110 - El follower 167917734 tiene 36 seguidores
# Follower --------->4056048214
# 111 - El follower 4056048214 tiene 10 seguidores
# Follower --------->773631878456803328
# 112 - El follower 773631878456803328 tiene 303 seguidores
# Follower --------->241468756
# 113 - El usuario 241468756 no nos deja acceder a sus datos
# Follower --------->985613825356500993
# 114 - El usuario 985613825356500993 no nos deja acceder a sus datos
# Follower --------->271973466
# 115 - El follower 271973466 tiene 99 seguidores
# Follower --------->3165991900
# Rate limit reached. Sleeping for: 888
# 116 - El follower 3165991900 tiene 52 seguidores
# Follower --------->350730772
# 117 - El follower 350730772 tiene 29 seguidores
# Follower --------->47873602
# 118 - El follower 47873602 tiene 31 seguidores
# Follower --------->174504385
# 119 - El follower 174504385 tiene 1551 seguidores
# Follower --------->225899540
# 120 - El follower 225899540 tiene 165 seguidores
# Follower --------->311528516
# 121 - El follower 311528516 tiene 23 seguidores
# Follower --------->3297779607
# 122 - El usuario 3297779607 no nos deja acceder a sus datos
# Follower --------->467128283
# 123 - El follower 467128283 tiene 556 seguidores
# Follower --------->586043084
# 124 - El follower 586043084 tiene 2496 seguidores
# Follower --------->950036469829300225
# 125 - El follower 950036469829300225 tiene 1 seguidores
# Follower --------->13937782
# 126 - El follower 13937782 tiene 399 seguidores
# Follower --------->1551361352
# 127 - El follower 1551361352 tiene 10 seguidores
# Follower --------->978963906327662594
# 128 - El follower 978963906327662594 tiene 34 seguidores
# Follower --------->165812101
# 129 - El follower 165812101 tiene 136 seguidores
# Follower --------->221855772
# 130 - El follower 221855772 tiene 415 seguidores
# Follower --------->223827791
# Rate limit reached. Sleeping for: 887
# 131 - El follower 223827791 tiene 136 seguidores
# Follower --------->2307402502
# 132 - El follower 2307402502 tiene 23 seguidores
# Follower --------->3011038312
# 133 - El follower 3011038312 tiene 88 seguidores
# Follower --------->3010529230
# 134 - El follower 3010529230 tiene 659 seguidores
# Follower --------->961649459548565505
# 135 - El follower 961649459548565505 tiene 178 seguidores
# Follower --------->4068749975
# 136 - El follower 4068749975 tiene 8 seguidores
# Follower --------->1569495691
# 137 - El follower 1569495691 tiene 70 seguidores
# Follower --------->2468861760
# 138 - El follower 2468861760 tiene 8 seguidores
# Follower --------->222213760
# 139 - El follower 222213760 tiene 25 seguidores
# Follower --------->130641617
# 140 - El follower 130641617 tiene 295 seguidores
# Follower --------->207711504
# 141 - El follower 207711504 tiene 179 seguidores
# Follower --------->811626216
# 142 - El follower 811626216 tiene 103 seguidores
# Follower --------->254535656
# 143 - El follower 254535656 tiene 638 seguidores
# Follower --------->136791007
# 144 - El follower 136791007 tiene 224 seguidores
# Follower --------->822915157366099968
# 145 - El follower 822915157366099968 tiene 83 seguidores
# Follower --------->151791942
# Rate limit reached. Sleeping for: 887
# 146 - El follower 151791942 tiene 104 seguidores
# Follower --------->854642433392603136
# 147 - El follower 854642433392603136 tiene 21 seguidores
# Follower --------->943155637399293952
# 148 - El follower 943155637399293952 tiene 748 seguidores
# Follower --------->157676244
# 149 - El follower 157676244 tiene 299 seguidores
# Follower --------->111061366
# 150 - El follower 111061366 tiene 78 seguidores
# Follower --------->135834707
# 151 - El follower 135834707 tiene 102 seguidores
# Follower --------->3360288975
# 152 - El follower 3360288975 tiene 15 seguidores
# Follower --------->967923054952304641
# 153 - El follower 967923054952304641 tiene 15 seguidores
# Follower --------->332640337
# 154 - El follower 332640337 tiene 553 seguidores
# Follower --------->2370076675
# 155 - El follower 2370076675 tiene 1556 seguidores
# Follower --------->911946638289199104
# 156 - El follower 911946638289199104 tiene 2208 seguidores
# Follower --------->198685614
# 157 - El follower 198685614 tiene 61 seguidores
# Follower --------->89132221
# 158 - El follower 89132221 tiene 454 seguidores
# Follower --------->539879851
# 159 - El follower 539879851 tiene 705 seguidores
# Follower --------->558832837
# 160 - El follower 558832837 tiene 242 seguidores
# Follower --------->973622511027085314
# Rate limit reached. Sleeping for: 888
# 161 - El follower 973622511027085314 tiene 388 seguidores
# Follower --------->834841700392636417
# 162 - El follower 834841700392636417 tiene 4 seguidores
# Follower --------->49654629
# 163 - El follower 49654629 tiene 106 seguidores
# Follower --------->634861352
# 164 - El follower 634861352 tiene 1748 seguidores
# Follower --------->872801480906035200
# 165 - El follower 872801480906035200 tiene 119 seguidores
# Follower --------->310669629
# 166 - El follower 310669629 tiene 331 seguidores
# Follower --------->591029527
# 167 - El follower 591029527 tiene 693 seguidores
# Follower --------->269989805
# 168 - El follower 269989805 tiene 776 seguidores
# Follower --------->970110074499883009
# 169 - El follower 970110074499883009 tiene 0 seguidores
# Follower --------->51878467
# 170 - El follower 51878467 tiene 185 seguidores
# Follower --------->366279977
# 171 - El follower 366279977 tiene 444 seguidores
# Follower --------->303673201
# 172 - El follower 303673201 tiene 1737 seguidores
# Follower --------->2290379794
# 173 - El usuario 2290379794 no nos deja acceder a sus datos
# Follower --------->77139229
# 174 - El follower 77139229 tiene 49 seguidores
# Follower --------->479515259
# 175 - El follower 479515259 tiene 805 seguidores
# Follower --------->93843354
# Rate limit reached. Sleeping for: 886
# 176 - El follower 93843354 tiene 712 seguidores
# Follower --------->301077550
# 177 - El follower 301077550 tiene 22 seguidores
# Follower --------->348126519
# 178 - El usuario 348126519 no nos deja acceder a sus datos
# Follower --------->629646374
# 179 - El follower 629646374 tiene 1427 seguidores
# Follower --------->140092403
# 180 - El follower 140092403 tiene 2855 seguidores
# Follower --------->754248284844204032
# 181 - El follower 754248284844204032 tiene 1212 seguidores
# Follower --------->396822806
# 182 - El follower 396822806 tiene 40 seguidores
# Follower --------->3059863859
# 183 - El follower 3059863859 tiene 41 seguidores
# Follower --------->952826125
# 184 - El follower 952826125 tiene 162 seguidores
# Follower --------->722701199754047488
# 185 - El follower 722701199754047488 tiene 1112 seguidores
# Follower --------->4921460097
# 186 - El follower 4921460097 tiene 47 seguidores
# Follower --------->372115252
# 187 - El follower 372115252 tiene 189 seguidores
# Follower --------->2214129848
# 188 - El follower 2214129848 tiene 300 seguidores
# Follower --------->919271583113498624
# 189 - El follower 919271583113498624 tiene 1176 seguidores
# Follower --------->20849192
# 190 - El follower 20849192 tiene 711 seguidores
# Follower --------->2838033844
# Rate limit reached. Sleeping for: 886
# 191 - El follower 2838033844 tiene 21 seguidores
# Follower --------->913421438991896576
# 192 - El follower 913421438991896576 tiene 17 seguidores
# Follower --------->925643101930250240
# 193 - El usuario 925643101930250240 no nos deja acceder a sus datos
# Follower --------->478997499
# 194 - El usuario 478997499 no nos deja acceder a sus datos
# Follower --------->940815164470939648
# 195 - El follower 940815164470939648 tiene 167 seguidores
# Follower --------->2915846445
# 196 - El follower 2915846445 tiene 665 seguidores
# Follower --------->950779528917512193
# 197 - El follower 950779528917512193 tiene 201 seguidores
# Follower --------->775496388
# 198 - El follower 775496388 tiene 113 seguidores
# Follower --------->156922766
# 199 - El follower 156922766 tiene 99 seguidores
# Follower --------->124424696
# 200 - El follower 124424696 tiene 69 seguidores
# Follower --------->250356573
# 201 - El usuario 250356573 no nos deja acceder a sus datos
# Follower --------->3081302315
# 202 - El follower 3081302315 tiene 6450 seguidores
# Follower --------->517813935
# 203 - El follower 517813935 tiene 452 seguidores
# Follower --------->914181903053393920
# 204 - El follower 914181903053393920 tiene 1 seguidores
# Follower --------->40976388
# Rate limit reached. Sleeping for: 887
# 205 - El follower 40976388 tiene 291 seguidores
# Follower --------->1378246098
# 206 - El follower 1378246098 tiene 56 seguidores
# Follower --------->219548713
# 207 - El usuario 219548713 no nos deja acceder a sus datos
# Follower --------->339520289
# 208 - El follower 339520289 tiene 190 seguidores
# Follower --------->322265056
# 209 - El follower 322265056 tiene 120 seguidores
# Follower --------->898217664321126401
# 210 - El follower 898217664321126401 tiene 110 seguidores
# Follower --------->253384020
# 211 - El follower 253384020 tiene 25 seguidores
# Follower --------->381164414
# 212 - El follower 381164414 tiene 22 seguidores
# Follower --------->906469877753565184
# 213 - El follower 906469877753565184 tiene 445 seguidores
# Follower --------->2313333082
# 214 - El follower 2313333082 tiene 20 seguidores
# Follower --------->799835817967493120
# 215 - El follower 799835817967493120 tiene 121 seguidores
# Follower --------->233626853
# 216 - El follower 233626853 tiene 950 seguidores
# Follower --------->1441349138
# 217 - El follower 1441349138 tiene 468 seguidores
# Follower --------->282605250
# 218 - El follower 282605250 tiene 273 seguidores
# Follower --------->945793340011933696
# 219 - El follower 945793340011933696 tiene 80 seguidores
# Follower --------->3064779449
# Rate limit reached. Sleeping for: 889
# 220 - El follower 3064779449 tiene 1043 seguidores
# Follower --------->286131887
# 221 - El follower 286131887 tiene 46 seguidores
# Follower --------->811244597028540417
# 222 - El follower 811244597028540417 tiene 1731 seguidores
# Follower --------->296804026
# 223 - El follower 296804026 tiene 176 seguidores
# Follower --------->543372693
# 224 - El follower 543372693 tiene 416 seguidores
# Follower --------->941282417213693952
# 225 - El follower 941282417213693952 tiene 194 seguidores
# Follower --------->1657256742
# 226 - El follower 1657256742 tiene 123 seguidores
# Follower --------->385893187
# 227 - El follower 385893187 tiene 6 seguidores
# Follower --------->101032110
# 228 - El follower 101032110 tiene 1 seguidores
# Follower --------->792172654434349056
# 229 - El follower 792172654434349056 tiene 3 seguidores
# Follower --------->938905392729423872
# 230 - El follower 938905392729423872 tiene 313 seguidores
# Follower --------->216652374
# 231 - El follower 216652374 tiene 2 seguidores
# Follower --------->353498005
# 232 - El follower 353498005 tiene 38 seguidores
# Follower --------->229972564
# 233 - El follower 229972564 tiene 72 seguidores
# Follower --------->795731197993295872
# 234 - El follower 795731197993295872 tiene 107 seguidores
# Follower --------->18305305
# Rate limit reached. Sleeping for: 887
# 235 - El follower 18305305 tiene 699 seguidores
# Follower --------->885802610518888448
# 236 - El follower 885802610518888448 tiene 1732 seguidores
# Follower --------->2527006736
# 237 - El follower 2527006736 tiene 9 seguidores
# Follower --------->710929095216001025
# 238 - El follower 710929095216001025 tiene 475 seguidores
# Follower --------->826729111636815872
# 239 - El follower 826729111636815872 tiene 1312 seguidores
# Follower --------->261752899
# 240 - El follower 261752899 tiene 49 seguidores
# Follower --------->888700807
# 241 - El follower 888700807 tiene 535 seguidores
# Follower --------->4134255287
# 242 - El follower 4134255287 tiene 6347 seguidores
# Follower --------->2610161142
# 243 - El follower 2610161142 tiene 11 seguidores
# Follower --------->929077990755094528
# 244 - El follower 929077990755094528 tiene 15 seguidores
# Follower --------->215781340
# 245 - El follower 215781340 tiene 105 seguidores
# Follower --------->2712261354
# 246 - El follower 2712261354 tiene 778 seguidores
# Follower --------->873354811
# 247 - El follower 873354811 tiene 973 seguidores
# Follower --------->4425699015
# 248 - El follower 4425699015 tiene 170 seguidores
# Follower --------->767981952
# Rate limit reached. Sleeping for: 887
# 249 - El follower 767981952 tiene 39 seguidores
# Follower --------->44861484
# 250 - El usuario 44861484 no nos deja acceder a sus datos
# Follower --------->66469337
# 251 - El follower 66469337 tiene 468 seguidores
# Follower --------->976296026
# 252 - El follower 976296026 tiene 39 seguidores
# Follower --------->221353124
# 253 - El follower 221353124 tiene 52 seguidores
# Follower --------->2810144116
# 254 - El follower 2810144116 tiene 5 seguidores
# Follower --------->388362342
# 255 - El follower 388362342 tiene 76 seguidores
# Follower --------->780641939154538497
# 256 - El usuario 780641939154538497 no nos deja acceder a sus datos
# Follower --------->760785007522840577
# 257 - El follower 760785007522840577 tiene 1023 seguidores
# Follower --------->807157805237080064
# 258 - El follower 807157805237080064 tiene 72 seguidores
# Follower --------->172980448
# 259 - El follower 172980448 tiene 386 seguidores
# Follower --------->77887672
# 260 - El follower 77887672 tiene 558 seguidores
# Follower --------->202245385
# 261 - El follower 202245385 tiene 896 seguidores
# Follower --------->1691447076
# 262 - El follower 1691447076 tiene 386 seguidores
# Follower --------->847372554574585856
# 263 - El follower 847372554574585856 tiene 30 seguidores
# Follower --------->2302878367
# Rate limit reached. Sleeping for: 887
# 264 - El usuario 2302878367 no nos deja acceder a sus datos
# Follower --------->314173831
# 265 - El follower 314173831 tiene 347 seguidores
# Follower --------->4204013255
# 266 - El follower 4204013255 tiene 1867 seguidores
# Follower --------->2288432504
# 267 - El follower 2288432504 tiene 478 seguidores
# Follower --------->3111388007
# 268 - El follower 3111388007 tiene 85 seguidores
# Follower --------->326319155
# 269 - El follower 326319155 tiene 162 seguidores
# Follower --------->903622203668930560
# 270 - El follower 903622203668930560 tiene 64 seguidores
# Follower --------->190591191
# 271 - El follower 190591191 tiene 781 seguidores
# Follower --------->4548953541
# 272 - El follower 4548953541 tiene 11706 seguidores
# Follower --------->56346738
# 273 - El follower 56346738 tiene 326 seguidores
# Follower --------->852522200502423552
# 274 - El follower 852522200502423552 tiene 18 seguidores
# Follower --------->62464753
# 275 - El follower 62464753 tiene 4114 seguidores
# Follower --------->486498249
# 276 - El follower 486498249 tiene 1610 seguidores
# Follower --------->1048446164
# Rate limit reached. Sleeping for: 887

# %%
#añadir el nodo de jecrespom
print(len(followers_d))

parent = api.get_user('jecrespom')
print(parent)
print(parent.id)
followers_jecrespom = api.followers_ids('jecrespom')
print(len(followers_jecrespom))
if parent.id not in followers_csv:
    followers_d = {parent.id: followers_jecrespom}
    print('añadido parent')
else:
    print('el parent ya está en el csv')

# %%
print(len(followers_d))
datos = []
for user_id in followers_d:
    for follower_id in followers_d[user_id]:
        enlace={'orig':user_id,
               'dest':follower_id}
        datos.append(enlace)
        #print(user_id,follower_id)
        
df = pd.DataFrame(datos)
df.info()
df_followers_csv.info()

#añado los que ya tengo. Concateno dos df
df_todos = pd.concat([df,df_followers_csv])

#guardo version2 del csv
df_todos.to_csv('grafo_followers_v2.csv',sep=' ',index=False,header=False)

#guardo los follower que no dejan acceder a sus datos, uno por línea
f = open("followers_acceso_no_permitido.txt", "a")
for line in acceso_no_permitido:
    f.write(line)
    f.write("\n")
f.close()

# %%
#análisis de grafo

# %%
import networkx
#--seguir---
